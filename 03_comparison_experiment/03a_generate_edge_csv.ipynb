# %%
import os
import sys
sys.path.append(os.path.join(os.getcwd(), '..'))

import yaml

import numpy as np
import pandas as pd

from arsenic import plotting, stats

from PLBenchmarks import targets, ligands, edges

from tqdm.notebook import tqdm
import pint
unit_registry = pint.UnitRegistry()

import benchmarkpl
path = benchmarkpl.__path__[0]
targets.set_data_dir(path)
# Out:
# Warning: Unable to load toolkit 'OpenEye Toolkit'. The Open Force Field Toolkit does not require the OpenEye Toolkits, and can use RDKit/AmberTools instead. However, if you have a valid license for the OpenEye Toolkits, consider installing them for faster performance and additional file format support: https://docs.eyesopen.com/toolkits/python/quickstart-python/linuxosx.html OpenEye offers free Toolkit licenses for academics: https://www.eyesopen.com/academic-licensing
# warning: inexact rename detection was skipped due to too many files.
# warning: you may want to set your diff.renameLimit variable to at least 69143 and retry the command.

# %%
names = ['Exp.', 
         'OpenFF-1.0', 
         'OpenFF-1.0_converged', 
         'OpenFF-1.2', 
         'OpenFF-1.2_converged', 
         'all edges off-2.0-rc1', 
         'converged II off-2.0-rc1', 
         'all edges off-2.0-part', 
         'converged II off-2.0-part', 
         'GAFF2', 
         'cGenFF', 
         'Consensus_OpenFF_GAFF2',
         'Consensus_OpenFF_GAFF2_cGenFF',
         'opls3e-gap', 
         'opls3e-per', 
         'opls3e-sch'
        ]

identifiers = ['experiment_hahn', 
               'pmx_openff-1.0.0.offxml_hahn', 
               'pmx_repeatfilter_openff-1.0.0.offxml_hahn', 
               'pmx_openff-1.2.0.offxml_gapsys', 
               'pmx_repeatfilter_openff-1.2.0.offxml_gapsys', 
               'pmx_openff-2.0.0-rc.1.offxml_gapsys', 
               'pmx_repeatfilter_openff-2.0.0-rc.1.offxml_gapsys', 
               'pmx_openff-2.0.0.offxml_gapsys', 
               'pmx_repeatfilter_openff-2.0.0.offxml_gapsys', 
               'pmx_gaff_gapsys', 
               'pmx_cgenff_gapsys', 
               'pmx_ogaff_gapsys', 
               'pmx_cgenogaff_gapsys', 
               'fep_opls3e_5_gapsys', 
               'fep+_opls3e_perez', 
               'fep+_opls3e_schindler'
              ]

# %%
data = {}
for target in tqdm(targets.target_dict.keys()):
    data[target] = {}
    for idx in identifiers:
        file_name = os.path.join(path, targets.get_target_dir(target), '10_results',
                                       f'{target}_{idx}.yaml'
                           )
        if os.path.exists(file_name):
            with open(file_name, 'r') as file:
                data[target][idx] = yaml.safe_load(file)
        else:
            print(f"File {file_name} for target {target} not available")
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-09-23_jnk1/10_results/jnk1_fep+_opls3e_perez.yaml for target jnk1 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-09-23_jnk1/10_results/jnk1_fep+_opls3e_schindler.yaml for target jnk1 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-09-23_pde2/10_results/pde2_pmx_openff-1.2.0.offxml_gapsys.yaml for target pde2 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-09-23_pde2/10_results/pde2_fep+_opls3e_perez.yaml for target pde2 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-09-23_pde2/10_results/pde2_fep+_opls3e_schindler.yaml for target pde2 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-09-23_thrombin/10_results/thrombin_fep+_opls3e_perez.yaml for target thrombin not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-09-23_thrombin/10_results/thrombin_fep+_opls3e_schindler.yaml for target thrombin not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-12-09_p38/10_results/p38_fep+_opls3e_perez.yaml for target p38 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-12-09_p38/10_results/p38_fep+_opls3e_schindler.yaml for target p38 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-12-12_ptp1b/10_results/ptp1b_fep+_opls3e_perez.yaml for target ptp1b not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-12-12_ptp1b/10_results/ptp1b_fep+_opls3e_schindler.yaml for target ptp1b not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-12-13_galectin/10_results/galectin_pmx_openff-1.2.0.offxml_gapsys.yaml for target galectin not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-12-13_galectin/10_results/galectin_fep+_opls3e_perez.yaml for target galectin not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-12-13_galectin/10_results/galectin_fep+_opls3e_schindler.yaml for target galectin not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-12-13_cdk2/10_results/cdk2_fep+_opls3e_perez.yaml for target cdk2 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-12-13_cdk2/10_results/cdk2_fep+_opls3e_schindler.yaml for target cdk2 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-12-13_cmet/10_results/cmet_pmx_openff-2.0.0.offxml_gapsys.yaml for target cmet not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-12-13_cmet/10_results/cmet_fep+_opls3e_perez.yaml for target cmet not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-12-13_mcl1/10_results/mcl1_fep+_opls3e_perez.yaml for target mcl1 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2019-12-13_mcl1/10_results/mcl1_fep+_opls3e_schindler.yaml for target mcl1 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-02-04_bace/10_results/bace_fep+_opls3e_perez.yaml for target bace not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-02-04_bace/10_results/bace_fep+_opls3e_schindler.yaml for target bace not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-02-05_bace_hunt/10_results/bace_hunt_pmx_openff-1.2.0.offxml_gapsys.yaml for target bace_hunt not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-02-05_bace_hunt/10_results/bace_hunt_pmx_openff-2.0.0-rc.1.offxml_gapsys.yaml for target bace_hunt not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-02-05_bace_hunt/10_results/bace_hunt_fep+_opls3e_perez.yaml for target bace_hunt not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-02-05_bace_hunt/10_results/bace_hunt_fep+_opls3e_schindler.yaml for target bace_hunt not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-02-06_bace_p2/10_results/bace_p2_pmx_openff-1.2.0.offxml_gapsys.yaml for target bace_p2 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-02-06_bace_p2/10_results/bace_p2_fep+_opls3e_perez.yaml for target bace_p2 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-02-06_bace_p2/10_results/bace_p2_fep+_opls3e_schindler.yaml for target bace_p2 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-02-07_tyk2/10_results/tyk2_fep+_opls3e_perez.yaml for target tyk2 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-02-07_tyk2/10_results/tyk2_fep+_opls3e_schindler.yaml for target tyk2 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-04-09_ros1/10_results/ros1_pmx_openff-1.2.0.offxml_gapsys.yaml for target ros1 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-04-09_ros1/10_results/ros1_fep_opls3e_5_gapsys.yaml for target ros1 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-04-09_ros1/10_results/ros1_fep+_opls3e_schindler.yaml for target ros1 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-06-19_eg5/10_results/eg5_fep_opls3e_5_gapsys.yaml for target eg5 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-06-19_eg5/10_results/eg5_fep+_opls3e_perez.yaml for target eg5 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-07-01_cdk8/10_results/cdk8_fep_opls3e_5_gapsys.yaml for target cdk8 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-07-01_cdk8/10_results/cdk8_fep+_opls3e_perez.yaml for target cdk8 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-07-03_hif2a/10_results/hif2a_fep_opls3e_5_gapsys.yaml for target hif2a not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-07-03_hif2a/10_results/hif2a_fep+_opls3e_perez.yaml for target hif2a not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-07-06_pfkfb3/10_results/pfkfb3_pmx_openff-2.0.0.offxml_gapsys.yaml for target pfkfb3 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-07-06_pfkfb3/10_results/pfkfb3_fep_opls3e_5_gapsys.yaml for target pfkfb3 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-07-06_pfkfb3/10_results/pfkfb3_fep+_opls3e_perez.yaml for target pfkfb3 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-07-10_pde10/10_results/pde10_pmx_openff-1.2.0.offxml_gapsys.yaml for target pde10 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-07-10_pde10/10_results/pde10_fep_opls3e_5_gapsys.yaml for target pde10 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-07-10_pde10/10_results/pde10_fep+_opls3e_schindler.yaml for target pde10 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-07-30_shp2/10_results/shp2_fep_opls3e_5_gapsys.yaml for target shp2 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-07-30_shp2/10_results/shp2_fep+_opls3e_perez.yaml for target shp2 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-08-11_syk/10_results/syk_fep_opls3e_5_gapsys.yaml for target syk not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-08-11_syk/10_results/syk_fep+_opls3e_perez.yaml for target syk not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-08-12_tnks2/10_results/tnks2_fep_opls3e_5_gapsys.yaml for target tnks2 not available
# File ./03_benchmark_analysis/benchmarkpl/benchmarkpl/2020-08-12_tnks2/10_results/tnks2_fep+_opls3e_perez.yaml for target tnks2 not available

# %%
def combine_sets(sets, idx_new, name_new):
    for target in targets.target_dict.keys():
        data[target][idx_new] = {}
        for idx in sets:
            if idx in data[target]:
                for key, item in data[target][idx].items():
                    if 'nan' in key:
                        print(idx, target, key, item)
                    if not np.isnan(item['DDG']):
                        data[target][idx_new][key] = item
    if idx_new not in identifiers:
        identifiers.append(idx_new)
    else:
        raise Exception("idx_new already in identifiers")
    if name_new not in names:
        names.append(name_new)
    else:
        raise Exception("name_new already in identifiers")
    print(identifiers, names)
    assert len(identifiers) == len(names)

combine_sets(['fep_opls3e_5_gapsys', 'fep+_opls3e_perez', 'fep+_opls3e_schindler'], 
             'fep+_opls3e',
            'OPLS3e')

combine_sets([f"pmx_openff-2.0.0.offxml_gapsys",
              f"pmx_openff-2.0.0-rc.1.offxml_gapsys"], 
             'openff-2.0', 
             'OpenFF-2.0')
combine_sets(['pmx_repeatfilter_openff-2.0.0.offxml_gapsys',
              'pmx_repeatfilter_openff-2.0.0-rc.1.offxml_gapsys'], 
             'openff-2.0_converged',
             'OpenFF-2.0_converged')
# Out:
# ['experiment_hahn', 'pmx_openff-1.0.0.offxml_hahn', 'pmx_repeatfilter_openff-1.0.0.offxml_hahn', 'pmx_openff-1.2.0.offxml_gapsys', 'pmx_repeatfilter_openff-1.2.0.offxml_gapsys', 'pmx_openff-2.0.0-rc.1.offxml_gapsys', 'pmx_repeatfilter_openff-2.0.0-rc.1.offxml_gapsys', 'pmx_openff-2.0.0.offxml_gapsys', 'pmx_repeatfilter_openff-2.0.0.offxml_gapsys', 'pmx_gaff_gapsys', 'pmx_cgenff_gapsys', 'pmx_ogaff_gapsys', 'pmx_cgenogaff_gapsys', 'fep_opls3e_5_gapsys', 'fep+_opls3e_perez', 'fep+_opls3e_schindler', 'fep+_opls3e'] ['Exp.', 'OpenFF-1.0', 'OpenFF-1.0_converged', 'OpenFF-1.2', 'OpenFF-1.2_converged', 'all edges off-2.0-rc1', 'converged II off-2.0-rc1', 'all edges off-2.0-part', 'converged II off-2.0-part', 'GAFF2', 'cGenFF', 'Consensus_OpenFF_GAFF2', 'Consensus_OpenFF_GAFF2_cGenFF', 'opls3e-gap', 'opls3e-per', 'opls3e-sch', 'OPLS3e']
# ['experiment_hahn', 'pmx_openff-1.0.0.offxml_hahn', 'pmx_repeatfilter_openff-1.0.0.offxml_hahn', 'pmx_openff-1.2.0.offxml_gapsys', 'pmx_repeatfilter_openff-1.2.0.offxml_gapsys', 'pmx_openff-2.0.0-rc.1.offxml_gapsys', 'pmx_repeatfilter_openff-2.0.0-rc.1.offxml_gapsys', 'pmx_openff-2.0.0.offxml_gapsys', 'pmx_repeatfilter_openff-2.0.0.offxml_gapsys', 'pmx_gaff_gapsys', 'pmx_cgenff_gapsys', 'pmx_ogaff_gapsys', 'pmx_cgenogaff_gapsys', 'fep_opls3e_5_gapsys', 'fep+_opls3e_perez', 'fep+_opls3e_schindler', 'fep+_opls3e', 'openff-2.0'] ['Exp.', 'OpenFF-1.0', 'OpenFF-1.0_converged', 'OpenFF-1.2', 'OpenFF-1.2_converged', 'all edges off-2.0-rc1', 'converged II off-2.0-rc1', 'all edges off-2.0-part', 'converged II off-2.0-part', 'GAFF2', 'cGenFF', 'Consensus_OpenFF_GAFF2', 'Consensus_OpenFF_GAFF2_cGenFF', 'opls3e-gap', 'opls3e-per', 'opls3e-sch', 'OPLS3e', 'OpenFF-2.0']
# ['experiment_hahn', 'pmx_openff-1.0.0.offxml_hahn', 'pmx_repeatfilter_openff-1.0.0.offxml_hahn', 'pmx_openff-1.2.0.offxml_gapsys', 'pmx_repeatfilter_openff-1.2.0.offxml_gapsys', 'pmx_openff-2.0.0-rc.1.offxml_gapsys', 'pmx_repeatfilter_openff-2.0.0-rc.1.offxml_gapsys', 'pmx_openff-2.0.0.offxml_gapsys', 'pmx_repeatfilter_openff-2.0.0.offxml_gapsys', 'pmx_gaff_gapsys', 'pmx_cgenff_gapsys', 'pmx_ogaff_gapsys', 'pmx_cgenogaff_gapsys', 'fep_opls3e_5_gapsys', 'fep+_opls3e_perez', 'fep+_opls3e_schindler', 'fep+_opls3e', 'openff-2.0', 'openff-2.0_converged'] ['Exp.', 'OpenFF-1.0', 'OpenFF-1.0_converged', 'OpenFF-1.2', 'OpenFF-1.2_converged', 'all edges off-2.0-rc1', 'converged II off-2.0-rc1', 'all edges off-2.0-part', 'converged II off-2.0-part', 'GAFF2', 'cGenFF', 'Consensus_OpenFF_GAFF2', 'Consensus_OpenFF_GAFF2_cGenFF', 'opls3e-gap', 'opls3e-per', 'opls3e-sch', 'OPLS3e', 'OpenFF-2.0', 'OpenFF-2.0_converged']

# %%
all_edges = pd.DataFrame()
for target, tdata in tqdm(data.items()):
    dfs = []
    for software, sdata in tdata.items():
        df = pd.DataFrame(sdata).T
        df['target'] = target
        df['edge'] = [f'edge_{row["ligandA"]}_{row["ligandB"]}' for i, row in df.iterrows()] 
        if df.shape[0]==0:
            continue
        for i, row in df.iterrows():
            df.loc[i, f'DDG_{software}'] = unit_registry.Quantity(row['DDG'], row['unit']).to('kilocalories/mole').magnitude
            df.loc[i, f'dDDG_{software}'] = unit_registry.Quantity(row['dDDG'], row['unit']).to('kilocalories/mole').magnitude
        df = df.drop(labels=['DDG', 'dDDG'], axis=1)
        dfs.append(df)
    if len(dfs) > 0:
        df = pd.concat(dfs, axis=1)
        df = df.loc[:,~df.columns.duplicated()]
        all_edges = all_edges.append(df)
all_edges.head()
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
#                            ligandA  ligandB                 unit target  \
# jnk1_edge_17124-1_18631-1  17124-1  18631-1  kilocalories / mole   jnk1
# jnk1_edge_17124-1_18634-1  17124-1  18634-1  kilocalories / mole   jnk1
# jnk1_edge_18626-1_18624-1  18626-1  18624-1  kilocalories / mole   jnk1
# jnk1_edge_18626-1_18625-1  18626-1  18625-1  kilocalories / mole   jnk1
# jnk1_edge_18626-1_18627-1  18626-1  18627-1  kilocalories / mole   jnk1
#
#                                            edge  DDG_experiment_hahn  \
# jnk1_edge_17124-1_18631-1  edge_17124-1_18631-1                 0.26
# jnk1_edge_17124-1_18634-1  edge_17124-1_18634-1                -0.33
# jnk1_edge_18626-1_18624-1  edge_18626-1_18624-1                 0.38
# jnk1_edge_18626-1_18625-1  edge_18626-1_18625-1                 0.77
# jnk1_edge_18626-1_18627-1  edge_18626-1_18627-1                 0.39
#
#                            dDDG_experiment_hahn  \
# jnk1_edge_17124-1_18631-1                  0.37
# jnk1_edge_17124-1_18634-1                  0.29
# jnk1_edge_18626-1_18624-1                  0.21
# jnk1_edge_18626-1_18625-1                  0.21
# jnk1_edge_18626-1_18627-1                  0.22
#
#                            DDG_pmx_openff-1.0.0.offxml_hahn  \
# jnk1_edge_17124-1_18631-1                          1.190000
# jnk1_edge_17124-1_18634-1                          0.580000
# jnk1_edge_18626-1_18624-1                          0.556667
# jnk1_edge_18626-1_18625-1                         -0.030000
# jnk1_edge_18626-1_18627-1                          0.140000
#
#                            dDDG_pmx_openff-1.0.0.offxml_hahn  \
# jnk1_edge_17124-1_18631-1                           0.096086
# jnk1_edge_17124-1_18634-1                           0.128639
# jnk1_edge_18626-1_18624-1                           0.099301
# jnk1_edge_18626-1_18625-1                           0.107462
# jnk1_edge_18626-1_18627-1                           0.046151
#
#                            DDG_pmx_repeatfilter_openff-1.0.0.offxml_hahn  ...  \
# jnk1_edge_17124-1_18631-1                                       1.190000  ...
# jnk1_edge_17124-1_18634-1                                       0.580000  ...
# jnk1_edge_18626-1_18624-1                                       0.556667  ...
# jnk1_edge_18626-1_18625-1                                      -0.030000  ...
# jnk1_edge_18626-1_18627-1                                       0.140000  ...
#
#                            DDG_fep+_opls3e  dDDG_fep+_opls3e  DDG_openff-2.0  \
# jnk1_edge_17124-1_18631-1         1.517686          0.069312        2.303333
# jnk1_edge_17124-1_18634-1         0.583174          0.043021        0.540000
# jnk1_edge_18626-1_18624-1         1.073136          0.040631        0.993333
# jnk1_edge_18626-1_18625-1         1.445985          0.033461        1.026667
# jnk1_edge_18626-1_18627-1         0.396750          0.081262        0.076667
#
#                            dDDG_openff-2.0  DDG_openff-2.0_converged  \
# jnk1_edge_17124-1_18631-1         0.171359                  2.303333
# jnk1_edge_17124-1_18634-1         0.112473                  0.540000
# jnk1_edge_18626-1_18624-1         0.093137                  0.993333
# jnk1_edge_18626-1_18625-1         0.179128                  1.026667
# jnk1_edge_18626-1_18627-1         0.172500                  0.076667
#
#                            dDDG_openff-2.0_converged  \
# jnk1_edge_17124-1_18631-1                   0.174821
# jnk1_edge_17124-1_18634-1                   0.109350
# jnk1_edge_18626-1_18624-1                   0.094997
# jnk1_edge_18626-1_18625-1                   0.178439
# jnk1_edge_18626-1_18627-1                   0.169267
#
#                            DDG_fep+_opls3e_schindler  \
# jnk1_edge_17124-1_18631-1                        NaN
# jnk1_edge_17124-1_18634-1                        NaN
# jnk1_edge_18626-1_18624-1                        NaN
# jnk1_edge_18626-1_18625-1                        NaN
# jnk1_edge_18626-1_18627-1                        NaN
#
#                            dDDG_fep+_opls3e_schindler  DDG_fep+_opls3e_perez  \
# jnk1_edge_17124-1_18631-1                         NaN                    NaN
# jnk1_edge_17124-1_18634-1                         NaN                    NaN
# jnk1_edge_18626-1_18624-1                         NaN                    NaN
# jnk1_edge_18626-1_18625-1                         NaN                    NaN
# jnk1_edge_18626-1_18627-1                         NaN                    NaN
#
#                            dDDG_fep+_opls3e_perez
# jnk1_edge_17124-1_18631-1                     NaN
# jnk1_edge_17124-1_18634-1                     NaN
# jnk1_edge_18626-1_18624-1                     NaN
# jnk1_edge_18626-1_18625-1                     NaN
# jnk1_edge_18626-1_18627-1                     NaN
#
# [5 rows x 43 columns]

# %%
all_edges.shape
# Out:
# (1128, 43)

# %%
all_edges.columns
# Out:
# Index(['ligandA', 'ligandB', 'unit', 'target', 'edge', 'DDG_experiment_hahn',
#        'dDDG_experiment_hahn', 'DDG_pmx_openff-1.0.0.offxml_hahn',
#        'dDDG_pmx_openff-1.0.0.offxml_hahn',
#        'DDG_pmx_repeatfilter_openff-1.0.0.offxml_hahn',
#        'dDDG_pmx_repeatfilter_openff-1.0.0.offxml_hahn',
#        'DDG_pmx_openff-1.2.0.offxml_gapsys',
#        'dDDG_pmx_openff-1.2.0.offxml_gapsys',
#        'DDG_pmx_repeatfilter_openff-1.2.0.offxml_gapsys',
#        'dDDG_pmx_repeatfilter_openff-1.2.0.offxml_gapsys',
#        'DDG_pmx_openff-2.0.0-rc.1.offxml_gapsys',
#        'dDDG_pmx_openff-2.0.0-rc.1.offxml_gapsys',
#        'DDG_pmx_repeatfilter_openff-2.0.0-rc.1.offxml_gapsys',
#        'dDDG_pmx_repeatfilter_openff-2.0.0-rc.1.offxml_gapsys',
#        'DDG_pmx_openff-2.0.0.offxml_gapsys',
#        'dDDG_pmx_openff-2.0.0.offxml_gapsys',
#        'DDG_pmx_repeatfilter_openff-2.0.0.offxml_gapsys',
#        'dDDG_pmx_repeatfilter_openff-2.0.0.offxml_gapsys',
#        'DDG_pmx_gaff_gapsys', 'dDDG_pmx_gaff_gapsys', 'DDG_pmx_cgenff_gapsys',
#        'dDDG_pmx_cgenff_gapsys', 'DDG_pmx_ogaff_gapsys',
#        'dDDG_pmx_ogaff_gapsys', 'DDG_pmx_cgenogaff_gapsys',
#        'dDDG_pmx_cgenogaff_gapsys', 'DDG_fep_opls3e_5_gapsys',
#        'dDDG_fep_opls3e_5_gapsys', 'DDG_fep+_opls3e', 'dDDG_fep+_opls3e',
#        'DDG_openff-2.0', 'dDDG_openff-2.0', 'DDG_openff-2.0_converged',
#        'dDDG_openff-2.0_converged', 'DDG_fep+_opls3e_schindler',
#        'dDDG_fep+_opls3e_schindler', 'DDG_fep+_opls3e_perez',
#        'dDDG_fep+_opls3e_perez'],
#       dtype='object')

# %%
# Remove irrelevant columns and reorder
all_edges = all_edges[['target', 'edge', 'ligandA', 'ligandB', 'unit', 
                       'DDG_experiment_hahn',
                       'dDDG_experiment_hahn', 
                       'DDG_pmx_openff-1.0.0.offxml_hahn',
                       'dDDG_pmx_openff-1.0.0.offxml_hahn',
                       'DDG_pmx_repeatfilter_openff-1.0.0.offxml_hahn',
                       'dDDG_pmx_repeatfilter_openff-1.0.0.offxml_hahn',
                       'DDG_pmx_openff-1.2.0.offxml_gapsys',
                       'dDDG_pmx_openff-1.2.0.offxml_gapsys',
                       'DDG_pmx_repeatfilter_openff-1.2.0.offxml_gapsys',
                       'dDDG_pmx_repeatfilter_openff-1.2.0.offxml_gapsys',
                       'DDG_openff-2.0', 
                       'dDDG_openff-2.0', 
                       'DDG_openff-2.0_converged',
                       'dDDG_openff-2.0_converged',
                       'DDG_fep+_opls3e', 
                       'dDDG_fep+_opls3e',
                       'DDG_pmx_gaff_gapsys', 
                       'dDDG_pmx_gaff_gapsys', 
                       'DDG_pmx_cgenff_gapsys',
                       'dDDG_pmx_cgenff_gapsys',
                       'DDG_pmx_cgenogaff_gapsys',
                       'dDDG_pmx_cgenogaff_gapsys',
                       'DDG_pmx_ogaff_gapsys',
                       'dDDG_pmx_ogaff_gapsys'
                      ]]

# %%
all_edges.rename(columns={f'DDG_{i}':f'DDG_{n}' for n, i in zip(names, identifiers)}, inplace=True)
all_edges.rename(columns={f'dDDG_{i}':f'dDDG_{n}' for n, i in zip(names, identifiers)}, inplace=True)

# %%
for key, row in all_edges.iterrows():  
    ddg = 0.0
    eddg = 0.0
    consensus_idx = ['OPLS3e',
                     'OpenFF-2.0',
                     'GAFF2',
                     'cGenFF']
    for idx in consensus_idx:
        ddg += row[f'DDG_{idx}']
        eddg += row[f'dDDG_{idx}']**2
    all_edges.loc[key, 'DDG_Consensus_all'] = ddg/float(len(consensus_idx))
    all_edges.loc[key, 'dDDG_Consensus_all'] = np.sqrt(eddg)/float(len(consensus_idx))

# %%
identifiers = [idx[4:] for idx in all_edges.columns if idx.startswith("DDG")]
identifiers
# Out:
# ['Exp.',
#  'OpenFF-1.0',
#  'OpenFF-1.0_converged',
#  'OpenFF-1.2',
#  'OpenFF-1.2_converged',
#  'OpenFF-2.0',
#  'OpenFF-2.0_converged',
#  'OPLS3e',
#  'GAFF2',
#  'cGenFF',
#  'Consensus_OpenFF_GAFF2_cGenFF',
#  'Consensus_OpenFF_GAFF2',
#  'Consensus_all']

# %%
for idx in identifiers:
    if idx != 'Exp.':
        all_edges[f'error_{idx}'] = all_edges[f'DDG_{idx}'] - all_edges['DDG_Exp.']
        all_edges.loc[:,f'abserror_{idx}'] = all_edges.loc[:,f'error_{idx}'].abs()
        print(idx,  all_edges.loc[:,f'abserror_{idx}'].mean())
# Out:
# OpenFF-1.0 1.2591962174940898
# OpenFF-1.0_converged 1.0877342549923195
# OpenFF-1.2 1.417208106473079
# OpenFF-1.2_converged 1.2412426532325778
# OpenFF-2.0 1.21385195035461
# OpenFF-2.0_converged 1.0171215686274508
# OPLS3e 1.0053877700233693
# GAFF2 1.1778856354727454
# cGenFF 1.3511330538717798
# Consensus_OpenFF_GAFF2_cGenFF 1.0764493974569338
# Consensus_OpenFF_GAFF2 1.193407425111536
# Consensus_all 0.9195052582755381

# %%
all_edges.to_csv('03a_all_edges_all_ffs.csv')
