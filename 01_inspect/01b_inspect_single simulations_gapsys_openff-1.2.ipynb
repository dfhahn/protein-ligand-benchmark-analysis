# %% [markdown]
# # Inspect data and search for failed simulations

# %%
import os
import re
import sys

import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from  plotly import colors
import pandas as pd

from rdkit import Chem
from rdkit.Chem import Draw, PandasTools, rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D, IPythonConsole

rdDepictor.SetPreferCoordGen(True)
from IPython.display import SVG
import rdkit

from svgutils import transform as sg

from IPython.core.display import HTML
from scipy.stats import norm

from PLBenchmarks import targets, ligands, edges

from tqdm.notebook import tqdm

sys.path.append(os.path.join(os.getcwd(), '..'))
import benchmarkpl
path = benchmarkpl.__path__[0]
targets.set_data_dir(path)
# Out:
# Warning: Unable to load toolkit 'OpenEye Toolkit'. The Open Force Field Toolkit does not require the OpenEye Toolkits, and can use RDKit/AmberTools instead. However, if you have a valid license for the OpenEye Toolkits, consider installing them for faster performance and additional file format support: https://docs.eyesopen.com/toolkits/python/quickstart-python/linuxosx.html OpenEye offers free Toolkit licenses for academics: https://www.eyesopen.com/academic-licensing
# _ColormakerRegistry()

# %% [markdown]
# # Read in data for Parsley forcefield

# %% [markdown]
# Function to read in data

# %%
from benchmarkpl import load_data

# %% [markdown]
# # load all data into one dataframe

# %%
forcefield = 'openff-1.2.0.offxml'
dfs = []
for target in tqdm(targets.target_dict):
    df = load_data.getDetailedResults(target, forcefield=forcefield)
    if df is None:
        continue
    for env in ['complex', 'water']:
        for rep in range(1,4):
            if str(rep) in df.columns.get_level_values(1):
                sub_df = df.loc[:, (env, str(rep), slice(None))].copy()
                sub_df.columns = sub_df.columns.get_level_values(2)
                sub_df['env'] = env
                sub_df['repeat'] = rep
                sub_df['target'] = target
                sub_df['edge'] = sub_df.index
                sub_df.reset_index(drop=True, inplace=True)
                dfs.append(sub_df)
all_sims = pd.concat(dfs, ignore_index=True)
all_sims.reset_index(drop=True, inplace=True)
all_sims.head()
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
#    val  err  aerr  conv      env  repeat target                  edge
# 0  NaN  NaN   NaN   NaN  complex       1   jnk1  edge_17124-1_18634-1
# 1  NaN  NaN   NaN   NaN  complex       1   jnk1  edge_18626-1_18624-1
# 2  NaN  NaN   NaN   NaN  complex       1   jnk1  edge_18636-1_18625-1
# 3  NaN  NaN   NaN   NaN  complex       1   jnk1  edge_18632-1_18624-1
# 4  NaN  NaN   NaN   NaN  complex       1   jnk1  edge_18635-1_18625-1

# %% [markdown]
# # Filter out simulations with run issues (nan values as results)

# %%
isna = all_sims.isna()
all_sims['failed'] = False
for i, row in isna.iterrows():
    if np.any(row):
        all_sims.loc[i, 'failed'] = True
print(f'There are {all_sims.loc[all_sims["failed"]].shape[0]} failed out of {all_sims.shape[0]} simulations')
all_sims.loc[all_sims['failed']]
# Out:
# There are 2960 failed out of 6264 simulations
#       val  err  aerr  conv      env  repeat target                  edge  \
# 0     NaN  NaN   NaN   NaN  complex       1   jnk1  edge_17124-1_18634-1
# 1     NaN  NaN   NaN   NaN  complex       1   jnk1  edge_18626-1_18624-1
# 2     NaN  NaN   NaN   NaN  complex       1   jnk1  edge_18636-1_18625-1
# 3     NaN  NaN   NaN   NaN  complex       1   jnk1  edge_18632-1_18624-1
# 4     NaN  NaN   NaN   NaN  complex       1   jnk1  edge_18635-1_18625-1
# ...   ...  ...   ...   ...      ...     ...    ...                   ...
# 4957  NaN  NaN   NaN   NaN    water       3  pde10        edge_8414_5644
# 4958  NaN  NaN   NaN   NaN    water       3  pde10        edge_5644_9211
# 4959  NaN  NaN   NaN   NaN    water       3  pde10        edge_5644_0309
# 4960  NaN  NaN   NaN   NaN    water       3  pde10        edge_5670_9211
# 4961  NaN  NaN   NaN   NaN    water       3  pde10        edge_5687_1801
#
#       failed
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# ...      ...
# 4957    True
# 4958    True
# 4959    True
# 4960    True
# 4961    True
#
# [2960 rows x 9 columns]

# %%
unique_failed_edges = {}

for i, row in tqdm(all_sims.loc[all_sims['failed']].iterrows()):
    target = row['target']
    edge = row['edge']
    env = row['env']
    repeat= row ['repeat']
    if not target in unique_failed_edges:
        unique_failed_edges[target] = {}
    if not edge in unique_failed_edges[target]:
        unique_failed_edges[target][edge] = {}
    if not env in unique_failed_edges[target][edge]:
        unique_failed_edges[target][edge][env] = []
    unique_failed_edges[target][edge][env].append(repeat)
unique_failed_edges
# Out:
# 0it [00:00, ?it/s]
# {'jnk1': {'edge_17124-1_18634-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18626-1_18624-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18636-1_18625-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18632-1_18624-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18635-1_18625-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18626-1_18658-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18639-1_18658-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18626-1_18625-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18638-1_18658-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18628-1_18624-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18631-1_18660-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18638-1_18634-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18626-1_18632-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18626-1_18630-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18631-1_18624-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18629-1_18627-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18634-1_18637-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18626-1_18627-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18631-1_18652-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18637-1_18631-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18626-1_18634-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18633-1_18624-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_17124-1_18631-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18627-1_18630-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18659-1_18634-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18636-1_18624-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18626-1_18628-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18626-1_18660-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18626-1_18659-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18639-1_18634-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18635-1_18624-1': {'complex': [1, 2, 3], 'water': [1, 2, 3]}},
#  'pde2': {'edge_49220392_49137530': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49932714_49137530': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49582468_49137530': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49396360_49137530': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_50181001_49137530': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49585367_49137530': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49220392_49175828': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49220548_49220392': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49220548_49932129': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49582468_49932129': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49396360_49175828': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49175828_49580115': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49220548_49137374': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49220548_49580115': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49396360_49220548': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49932714_49582390': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49396360_49582390': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_50181001_49582390': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_50107616_49582390': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_48168913_48271249': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49072088_48271249': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_50107616_48271249': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49137374_48271249': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49932714_49175789': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49932714_49580115': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49932714_49582468': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_48168913_49585367': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_50107616_49585367': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_48168913_48022468': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_43249674_48022468': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_48009208_43249674': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_43249674_49175789': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49175789_49072088': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_48009208_49137374': {'complex': [1, 2, 3], 'water': [1, 2, 3]}},
#  'thrombin': {'edge_1d_6e': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1d_5': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1b_3b': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_6a_1b': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1b_1c': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1d_1c': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1b_1a': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1a_5': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_3a_1d': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_6a_6b': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1d_7a': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1b_7a': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_3a_1b': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1d_1a': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1a_3b': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_6e_6b': {'complex': [1, 2, 3], 'water': [1, 2, 3]}},
#  'p38': {'edge_p38a_2u_p38a_2q': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fln_p38a_2g': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2u_p38a_2k': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2v_p38a_3fln': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fln_p38a_2n': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2ee_p38a_3fln': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fly_p38a_3flq': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fln_p38a_2p': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fly_p38a_2x': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2v_p38a_2y': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2j_p38a_2f': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2j_p38a_2q': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2z_p38a_3fmk': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fly_p38a_3fmh': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2z_p38a_2aa': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fln_p38a_2gg': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2v_p38a_3fly': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2j_p38a_2h': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2l_p38a_2o': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fln_p38a_2t': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2v_p38a_2x': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2j_p38a_2ff': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2g_p38a_2c': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2l_p38a_2p': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2g_p38a_2h': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fln_p38a_2o': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2gg_p38a_2j': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fln_p38a_2r': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fln_p38a_2i': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2z_p38a_3flw': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2g_p38a_2i': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3flz_p38a_2c': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2ee_p38a_2j': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2m_p38a_2j': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2t_p38a_2j': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2j_p38a_2r': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2e_p38a_2j': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2v_p38a_3fmh': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2v_p38a_3fmk': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2aa_p38a_2bb': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fln_p38a_2s': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2v_p38a_2j': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2v_p38a_2bb': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2l_p38a_2j': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2z_p38a_2y': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fln_p38a_3flz': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2z_p38a_3flq': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2l_p38a_2n': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fln_p38a_2e': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2m_p38a_2k': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3flz_p38a_2g': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2aa_p38a_3flw': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2s_p38a_2l': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_2g_p38a_2f': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fln_p38a_2k': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_p38a_3fln_p38a_2ff': {'complex': [1, 2, 3], 'water': [1, 2, 3]}},
#  'ptp1b': {'edge_23466_23475': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23467_23466': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23467_23468': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23467_23469': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23467_23470': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23467_23473': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23467_23474': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23467_23475': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23467_23476': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23469_23472': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23469_20669_2qbr': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23471_23466': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23471_23468': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23471_23470': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23473_20669_2qbr': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23474_23466': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23476_23466': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23477_23466': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23477_23467': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23477_23479': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23477_23482': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23477_23483': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23477_23330_2qbq': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23480_23479': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23480_23482': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23482_23479': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23482_23485': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23482_23486': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23483_23479': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23484_23479': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23484_23482': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23484_23485': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23484_23486': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23485_23479': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23486_23479': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23486_23485': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20667_2qbp_23479': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20667_2qbp_23482': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20667_2qbp_23484': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20667_2qbp_23485': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20667_2qbp_23486': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20669_2qbr_23466': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20669_2qbr_23472': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20670_2qbs_23466': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20670_2qbs_23477': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20670_2qbs_23479': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20670_2qbs_23482': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20670_2qbs_23483': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20670_2qbs_23330_2qbq': {'complex': [1, 2, 3], 'water': [1, 2, 3]}},
#  'galectin': {'edge_02_ligOMe_05_ligOEt': {'complex': [1, 2, 3],
#    'water': [1, 2, 3]},
#   'edge_07_ligOH_02_ligOMe': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_07_ligOH_01_ligF': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_03_ligNHMe_02_ligOMe': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_03_ligNHMe_04_ligNMe2': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_04_ligNMe2_08_ligNH2': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_06_ligPyr_01_ligF': {'complex': [1, 2, 3], 'water': [1, 2, 3]}},
#  'cdk2': {'edge_22_1h1r': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1h1s_1oiy': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1oiu_26': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_26_1h1q': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_17_1h1q': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1oiy_1oi9': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_29_26': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1h1s_26': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_28_26': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_17_21': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_28_31': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1h1r_1oi9': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1h1r_21': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_30_26': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1oiy_32': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_17_22': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_26_1oi9': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1oiy_29': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1oiy_31': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_31_32': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1oi9_20': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20_1h1q': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1oiy_1h1q': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1oiu_1h1q': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_30_31': {'complex': [1, 2, 3], 'water': [1, 2, 3]}},
#  'mcl1': {'edge_50_60': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_56_35': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_65_60': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_26_57': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_58_60': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_62_45': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_60_36': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_30_27': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_33_27': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_43_27': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_67_58': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_67_32': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_30_40': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_38_60': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_41_35': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_54_23': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_56_60': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_66_42': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_29_40': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_26_44': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49_35': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_29_35': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_42_51': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_39_32': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_35_37': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_28_35': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_35_53': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_67_63': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_27_45': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_41_32': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_67_53': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_35_33': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_27_46': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_66_23': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_67_61': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_57_23': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_30_35': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_61_60': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_67_31': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_32_46': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_35_60': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_31_35': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_62_26': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_35_36': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_26_64': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_38_35': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_35_34': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_29_27': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_48_27': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_68_45': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_63_60': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_54_42': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_44_23': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_28_27': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_67_27': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_52_60': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_27_23': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_49_67': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_28_47': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_67_52': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_30_48': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_67_35': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_32_34': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_65_67': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_67_50': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_35_39': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_43_47': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_67_37': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_42_64': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_51_45': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_68_23': {'complex': [1, 2, 3], 'water': [1, 2, 3]}},
#  'bace': {'edge_CAT-13b_CAT-17g': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13a_CAT-17g': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13e_CAT-17g': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4m_CAT-4c': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13k_CAT-4d': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-24_CAT-17e': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13g_CAT-17g': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13d_CAT-13h': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13a_CAT-17i': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4m_CAT-13j': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13a_CAT-13m': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4l_CAT-13k': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13o_CAT-17i': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4c_CAT-4o': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4j_CAT-4o': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4i_CAT-13m': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-24_CAT-17i': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13j_CAT-4o': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4n_CAT-13k': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4o_CAT-4b': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-17i_CAT-13f': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-17c_CAT-17e': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13k_CAT-4b': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4m_CAT-4j': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13n_CAT-13k': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13d_CAT-17h': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-17b_CAT-13d': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4m_CAT-4n': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4m_CAT-13k': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13c_CAT-17i': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4a_CAT-4o': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13h_CAT-17i': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4o_CAT-4d': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-17g_CAT-17c': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4a_CAT-13k': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13d_CAT-17d': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-17g_CAT-17f': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13e_CAT-17i': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13d_CAT-13b': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-17g_CAT-13i': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4m_CAT-13m': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-17g_CAT-13c': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-17i_CAT-17a': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13d_CAT-13f': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-17f_CAT-17e': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13d_CAT-17a': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-17g_CAT-17d': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13n_CAT-13a': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13o_CAT-17h': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-17b_CAT-17e': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4k_CAT-4o': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4m_CAT-4l': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4m_CAT-4k': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13n_CAT-4i': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13g_CAT-17i': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4p_CAT-13k': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-4m_CAT-4p': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_CAT-13d_CAT-13i': {'complex': [1, 2, 3], 'water': [1, 2, 3]}},
#  'bace_hunt': {'edge_33_13': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_33_25': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_31_33': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_12_33': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_28_34': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_28_37': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_28_23': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_22_32': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_22_16': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_26_32': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_26_14': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_16_26': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_37_34': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_19_37': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1a_37': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_27_37': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_35_37': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_21_37': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_30_20': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_30_13': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_30_21': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_30_39': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1a_40': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_29_40': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_19_25': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_13_25': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_25_14': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_12_25': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_31_36': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_31_13': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_38_31': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_24_1a': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1a_32': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_29_1a': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1a_18': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_41_1a': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_38_27': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_27_14': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_24_14': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_12_14': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18_14': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_39_14': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_17_34': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_17_38': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_39_36': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_23_36': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_11_24': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_11_35': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_11_19': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_11_21': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_38_34': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20_34': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_24_35': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_20_32': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_21_38': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_19_15': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18_19': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_16_15': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_41_29': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_18_39': {'complex': [1, 2, 3], 'water': [1, 2, 3]}},
#  'bace_p2': {'edge_32_L_31_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_32_L_29_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_32_L_35_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_32_L_30_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_28_L_35_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_39_L_35_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_35_L_29_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_39_L_34_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_39_L_37_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_39_L_28_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_39_L_36_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_31_L_30_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_31_L_29_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_34_L_29_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_34_L_30_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_34_L_36_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_37_L_36_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_28_L_36_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_38_L_36_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_33_L_30_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_30_L_29_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_33_L_29_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_28_L_38_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_28_L_29_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_28_L_37_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_38_L_37_L': {'complex': [1, 2, 3], 'water': [1, 2, 3]}},
#  'tyk2': {'edge_jmc_23_ejm_55': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_44_ejm_55': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_49_ejm_31': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_31_ejm_46': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_jmc_28_jmc_27': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_42_ejm_48': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_31_ejm_43': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_50_ejm_42': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_42_ejm_55': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_jmc_23_ejm_46': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_31_ejm_45': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_55_ejm_54': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_45_ejm_42': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_31_jmc_28': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_31_ejm_48': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_47_ejm_31': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_47_ejm_55': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_44_ejm_42': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_jmc_23_jmc_27': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_43_ejm_55': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_jmc_23_jmc_30': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_jmc_28_jmc_30': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_42_ejm_54': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_ejm_49_ejm_50': {'complex': [1, 2, 3], 'water': [1, 2, 3]}},
#  'eg5': {'edge_CHEMBL1083517_CHEMBL1085666': {'water': [2]}},
#  'cdk8': {'edge_30_33': {'complex': [3]}},
#  'pde10': {'edge_7395_3484': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_7395_0738': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_8041_4415': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_4189_4415': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1939_3032': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_5544_3806': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_4754_4147': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_3806_6221': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_3806_0340': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_3806-mvEster_0340': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_3806_1423': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_3806-mvEster_1423': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_3806_5973': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_3806-mvEster_5973': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_4096_4147': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_4147_2750': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_4147_7846': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_6694_4147': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1038_9211': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1038_0309': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_1038_0848': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_9211_1056': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_9211_9237': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_9211_0848': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_2333_9211': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_2333_0309': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_2333_0848': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_0395_8161': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_8414_1038': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_8414_1056': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_8414_2333': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_8414_5644': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_5644_9211': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_5644_0309': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_5670_9211': {'complex': [1, 2, 3], 'water': [1, 2, 3]},
#   'edge_5687_1801': {'complex': [1, 2, 3], 'water': [1, 2, 3]}}}

# %%
from benchmarkpl import drawing

d2ds = []
if os.path.exists('../../../02_benchmark_calculations/'):
    targets.set_data_dir('../../../02_benchmark_calculations/')
for target in unique_failed_edges.keys():
    eSet = edges.EdgeSet(target)
    for edge in unique_failed_edges[target].keys():
        print(target)
        df = eSet[edge].get_dataframe()
        df['target'] = target
        
        text = ''
        for env in unique_failed_edges[target][edge].keys():
            text+=(f'{env} (repeats {", ".join([str(rep) for rep in unique_failed_edges[target][edge][env]])}), ')
        text += f'DDG_exp = {df["exp. DeltaG [kcal/mol]"].magnitude}'\
            f' ({df["exp. Error [kcal/mol]"].magnitude}) kcal/mol'
        
        # check whether image exists
        os.makedirs(os.path.join(path, targets.get_target_dir(target), '11_failed'), exist_ok=True)
        file_path = os.path.join(path, targets.get_target_dir(target), '11_failed', f'{edge}.svg')
        if os.path.exists(file_path):
            with open(file_path, 'r') as file:
                img = file.read()
        else:
            # visualization
            m1 = Chem.SDMolSupplier(f'{targets.data_path}/{targets.get_target_dir(target)}/02_ligands/lig_{df[0]}/crd/lig_{df[0]}.sdf', removeHs=False)[0]
            m2 = Chem.SDMolSupplier(f'{targets.data_path}/{targets.get_target_dir(target)}/02_ligands/lig_{df[1]}/crd/lig_{df[1]}.sdf', removeHs=False)[0]
            pairs = np.loadtxt(f'{targets.data_path}/{targets.get_target_dir(target)}/03_hybrid/edge_{df[0]}_{df[1]}/water/crd/pairs.dat')
            # decrement pairs to match rdkit counting from 0!
            pairs -= 1
            img = drawing.drawPerturbation(m1, # rdkit molecule 1
                                           m2, # rdkit molecule 2
                                           pairs, # pairs, np array or list of lists
                                           target=target, # string with target name
                                           n1=df[0], # name mol 1
                                           n2=df[1], # name  mol 2
                                           text=text# additional text
                                  )

            with open(file_path, 'w') as file:
                file.write(img)
        #df['img'] = drawPerturbation(m1, m2, pairs, target=t, n1=df[0], n2=df[1]).GetDrawingText()
        d2ds.append(img)

HTML(''.join(d2ds))
# Out:
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# jnk1
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# pde2
# thrombin
# thrombin
# thrombin
# thrombin
# thrombin
# thrombin
# thrombin
# thrombin
# thrombin
# thrombin
# thrombin
# thrombin
# thrombin
# thrombin
# thrombin
# thrombin
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# p38
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# ptp1b
# galectin
# galectin
# galectin
# galectin
# galectin
# galectin
# galectin
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# cdk2
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# mcl1
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_hunt
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# bace_p2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# tyk2
# eg5
# cdk8
# pde10
# pde10
# pde10
# pde10
# pde10
# pde10
# pde10
# pde10
# pde10
# pde10
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_240715/3397022719.py in <module>
#       8     for edge in unique_failed_edges[target].keys():
#       9         print(target)
# ---> 10         df = eSet[edge].get_dataframe()
#      11         df['target'] = target
#      12
#
# KeyError: 'edge_3806-mvEster_0340'

# %%
#HTML(nanEdges.to_html())

# %%
#save failed edges to separate csv file and remove them from dataframe
all_sims.loc[all_sims['failed']].to_csv(f'failed_simulations_{forcefield}.csv')
all_sims = all_sims.drop(labels=all_sims.loc[all_sims['failed']].index, axis=0)
all_sims.head()

# %%
# save finished simulations
all_sims.to_csv(f'finished_simulations_{forcefield}.csv')

# %% [markdown]
# # Look at convergence criteria and set a criterion

# %%
# Extract convergence 
conv_thres = 0.8
all_sims['bConv'] = all_sims['conv'] < conv_thres
print(f'Simulations converged (Convergence < {conv_thres}):\n\
in water: {all_sims["bConv"].loc[all_sims["env"]=="water"].sum()} \
out of {all_sims.loc[all_sims["env"]=="water"].shape[0]}\n\
in complex: {all_sims["bConv"].loc[all_sims["env"]=="complex"].sum()} \
out of {all_sims.loc[all_sims["env"]=="complex"].shape[0]} simulations.')

# %%
# Extract convergence
err_thres = 1.0
all_sims['bErr'] = (all_sims['err'] < err_thres).values
print(f'Simulations converged (Bootstrap error < {err_thres}):\n\
in water: {all_sims["bErr"].loc[all_sims["env"]=="water"].sum()} \
out of {all_sims.loc[all_sims["env"]=="water"].shape[0]}\n\
in complex: {all_sims["bErr"].loc[all_sims["env"]=="complex"].sum()} \
out of {all_sims.loc[all_sims["env"]=="complex"].shape[0]} simulations.')

# %%
# Extract convergence
aerr_thres = 1.0
all_sims['bAerr'] = (all_sims['aerr'] < aerr_thres).values
print(f'Simulations converged (Analytical error < {aerr_thres}):\n\
in water: {all_sims["bAerr"].loc[all_sims["env"]=="water"].sum()} \
out of {all_sims.loc[all_sims["env"]=="water"].shape[0]}\n\
in complex: {all_sims["bAerr"].loc[all_sims["env"]=="complex"].sum()} \
out of {all_sims.loc[all_sims["env"]=="complex"].shape[0]} simulations.')

# %%
all_sims['include'] = all_sims['bAerr'] & all_sims['bConv']
print(f'Included simulations:\n\
in water: {all_sims["include"].loc[all_sims["env"]=="water"].sum()} \
out of {all_sims.loc[all_sims["env"]=="water"].shape[0]}\n\
in complex: {all_sims["include"].loc[all_sims["env"]=="complex"].sum()} \
out of {all_sims.loc[all_sims["env"]=="complex"].shape[0]} simulations.')

# %%
import itertools
import plotly
cols = plotly.colors.DEFAULT_PLOTLY_COLORS

fig = make_subplots(rows=2, cols=2, shared_xaxes=True, shared_yaxes=True)

# Add traces
col = 0
for env, rep in itertools.product(['water', 'complex'], ['1', '2', '3']):
    idx = np.logical_and(all_sims['env']==env, all_sims['repeat'] == int(rep))
    conv = all_sims.loc[idx, 'conv']
    aerr = all_sims.loc[idx, 'aerr']
    err = all_sims.loc[idx, 'err']
    text = [f'{row["target"]}:{row["edge"]}' for i, row in all_sims.loc[idx].iterrows()]
    if env == 'water':
        col=0
    else:
        col=1
    fig.add_trace(go.Scatter(x=conv, y=aerr,
                    mode='markers',
                    hovertext=text,
                    name=f'{env}',
                    opacity=.8,
                    marker_color=cols[col%6]), 
                 col=1,
                 row=1)
    fig.add_trace(go.Scatter(x=aerr, y=err,
                    mode='markers',
                    hovertext=text,
                    name=f'{env}',
                    marker_color=cols[col%6],
                    opacity=.8,
                    showlegend=False), 
                 col=2,
                 row=2)
    fig.add_trace(go.Scatter(x=conv, y=err,
                    mode='markers',
                    hovertext=text,
                    name=f'{env}',
                    opacity=.8,
                    marker_color=cols[col%6],
                    showlegend=False), 
                 col=1,
                 row=2)
fig.add_trace(go.Scatter(x=all_sims.loc[np.invert(all_sims['include']), 'conv'], 
                         y=all_sims.loc[np.invert(all_sims['include']), 'aerr'],
            mode='markers',
            name=f'not converged',
            opacity=.8,
                         marker_size=3,
            marker_color='black',
            showlegend=False), 
         col=1,
         row=1)
fig.add_trace(go.Scatter(x=all_sims.loc[np.invert(all_sims['include']), 'conv'], 
                         y=all_sims.loc[np.invert(all_sims['include']), 'err'],
            mode='markers',
            name=f'not converged',
            opacity=.8,
                         marker_size=3,
            marker_color='black',
            showlegend=False), 
         col=1,
         row=2)
fig.add_trace(go.Scatter(x=all_sims.loc[np.invert(all_sims['include']), 'aerr'], 
                         y=all_sims.loc[np.invert(all_sims['include']), 'err'],
            mode='markers',
            name=f'not converged',
            opacity=.8,
                         marker_size=3,
            marker_color='black',
            showlegend=False), 
         col=2,
         row=2)
fig.update_layout(
    yaxis3 = dict(title='Bootstrap Error [kcal mol<sup>-1</sup>]'),
    xaxis3=dict(title='Convergence'), 
    yaxis=dict(range=[0,5], title='Analytical Error [kcal mol<sup>-1</sup>]'),
    xaxis4=dict(range=[0,5], title='Analytical Error [kcal mol<sup>-1</sup>]'),)
fig.show()

# %%
unique_nonconverged_edges = {}

for i, row in tqdm(all_sims.loc[np.invert(all_sims['include'])].iterrows()):
    target = row['target']
    edge = row['edge']
    env = row['env']
    repeat= row ['repeat']
    if not target in unique_nonconverged_edges:
        unique_nonconverged_edges[target] = {}
    if not edge in unique_nonconverged_edges[target]:
        unique_nonconverged_edges[target][edge] = {}
    if not env in unique_nonconverged_edges[target][edge]:
        unique_nonconverged_edges[target][edge][env] = []
    unique_nonconverged_edges[target][edge][env].append(repeat)
unique_nonconverged_edges

# %%
d2ds = []
if os.path.exists('../../../02_benchmark_calculations/'):
    targets.set_data_dir('../../../02_benchmark_calculations/')
for target in unique_nonconverged_edges.keys():
    eSet = edges.EdgeSet(target)
    for edge in unique_nonconverged_edges[target].keys():
        df = eSet[edge].get_dataframe()
        df['target'] = target
        
        text = ''
        for env in unique_nonconverged_edges[target][edge].keys():
            text+=(f'{env} (repeats {", ".join([str(rep) for rep in unique_nonconverged_edges[target][edge][env]])}), ')
        text += f'DDG_exp = {df["exp. DeltaG [kcal/mol]"].magnitude}'\
            f' ({df["exp. Error [kcal/mol]"].magnitude}) kcal/mol'
        
        # check whether image exists
        os.makedirs(os.path.join(path, targets.get_target_dir(target), '12_not_converged'), exist_ok=True)
        file_path = os.path.join(path, targets.get_target_dir(target), '12_not_converged', f'{edge}.svg')
        if os.path.exists(file_path):
            with open(file_path, 'r') as file:
                img = file.read()
        else:
            # visualization
            m1 = Chem.SDMolSupplier(f'{targets.data_path}/{targets.get_target_dir(target)}/02_ligands/lig_{df[0]}/crd/lig_{df[0]}.sdf', removeHs=False)[0]
            m2 = Chem.SDMolSupplier(f'{targets.data_path}/{targets.get_target_dir(target)}/02_ligands/lig_{df[1]}/crd/lig_{df[1]}.sdf', removeHs=False)[0]
            pairs = np.loadtxt(f'{targets.data_path}/{targets.get_target_dir(target)}/03_hybrid/edge_{df[0]}_{df[1]}/water/crd/pairs.dat')
            # decrement pairs to match rdkit counting from 0!
            pairs -= 1
            img = drawing.drawPerturbation(m1, # rdkit molecule 1
                                   m2, # rdkit molecule 2
                                   pairs, # pairs, np array or list of lists
                                   target=target, # string with target name
                                   n1=df[0], # name mol 1
                                   n2=df[1], # name  mol 2
                                   text=text# additional text
                                  )

            with open(file_path, 'w') as file:
                file.write(img)
        #df['img'] = drawPerturbation(m1, m2, pairs, target=t, n1=df[0], n2=df[1]).GetDrawingText()
        d2ds.append(img)

HTML(''.join(d2ds))

# %% [markdown]
# # Filter out non-converged simulations

# %%
# remove non-converged simulations and save converged simulations to file
all_sims = all_sims.drop(labels=all_sims.loc[np.invert(all_sims['include'])].index, axis=0)
all_sims = all_sims.drop(labels=['include', 'failed', 'bConv', 'bErr', 'bAerr'], axis=1)
all_sims.to_csv(f'converged_simulations_{forcefield}.csv')
all_sims.head()
