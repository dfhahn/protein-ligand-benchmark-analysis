# %% [markdown]
# # Gather data from various source into the analysis repository

# %%
# imports
import os
import shutil
import numpy as np
import pandas as pd
import yaml
import git
import tempfile
import sys
sys.path.append(os.path.join(os.getcwd(), '..'))

import pint
unit_registry = pint.UnitRegistry()

from PLBenchmarks import targets, ligands, edges
from IPython.core.display import HTML

from tqdm.notebook import tqdm

import benchmarkpl
path = benchmarkpl.__path__[0]
# Out:
# Warning: Unable to load toolkit 'OpenEye Toolkit'. The Open Force Field Toolkit does not require the OpenEye Toolkits, and can use RDKit/AmberTools instead. However, if you have a valid license for the OpenEye Toolkits, consider installing them for faster performance and additional file format support: https://docs.eyesopen.com/toolkits/python/quickstart-python/linuxosx.html OpenEye offers free Toolkit licenses for academics: https://www.eyesopen.com/academic-licensing
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/envs/off/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     916             method = get_real_method(obj, self.print_method)
#     917             if method is not None:
# --> 918                 method()
#     919                 return True
#     920
#
# ~/miniconda3/envs/off/lib/python3.7/site-packages/nglview/color.py in _ipython_display_(self, **kwargs)
#      52         if self._ready:
#      53             return
# ---> 54         super()._ipython_display_(**kwargs)
#      55
#      56     def add_selection_scheme(self, scheme_id, arg):
#
# AttributeError: 'super' object has no attribute '_ipython_display_'
# _ColormakerRegistry()

# %% [markdown]
# # Set path of data directory

# %%
targets.set_data_dir(os.path.join(path))
# directory name where results for each target are stored
results_dir = '10_results'

# %% [markdown]
# # Number of targets, ligands and edges in the data set

# %%
nligs, nedgs = 0, 0
print(f'{"Target":10s} {"Num Ligs":>10s} {"Num Edges":>10s}')
print(33 * '-')
for target in tqdm(targets.target_dict):
    print(f'{target:10s} {len(ligands.LigandSet(target)):10d} {len(edges.EdgeSet(target)):10d}')
    nligs += len(ligands.LigandSet(target))
    nedgs += len(edges.EdgeSet(target))
print(33 * '-')
print(f'{"total":10s} {nligs:10d} {nedgs:10d}')
# Out:
# Target       Num Ligs  Num Edges
# ---------------------------------
#   0%|          | 0/22 [00:00<?, ?it/s]
# /home/dhahn3/miniconda3/envs/off/lib/python3.7/site-packages/pandas/core/dtypes/cast.py:1638: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
# jnk1               21         31
# pde2               21         34
# thrombin           11         16
# p38                34         56
# ptp1b              23         49
# galectin            8          7
# cdk2               16         25
# cmet               24         57
# mcl1               42         71
# bace               36         58
# bace_hunt          32         60
# bace_p2            12         26
# tyk2               16         24
# ros1               28         61
# eg5                28         65
# cdk8               33         54
# hif2a              42         92
# pfkfb3             40         66
# pde10              35         59
# shp2               26         56
# syk                44        101
# tnks2              27         60
# ---------------------------------
# total             599       1128

# %% [markdown]
# # Experimental values stored in repository
# Retrieve the experimental values stored in the dataset

# %%
ligs = ligands.LigandSet('pde10')
yaml.load?
#('../benchmarkpl/2020-07-10_pde10/00_data/ligands.yml')

# %%
# function to retrieve exp. data from PLBenchmarks 
def getExpResults(target):
    edg = edges.EdgeSet(target)
    df = edg.get_dataframe(columns=[0,1, 'exp. DeltaG [kcal/mol]', 'exp. Error [kcal/mol]'])
    df.index = pd.Series([f'{target}_edge_' + str(lig1) + '_' + str(lig2) for lig1, lig2 in zip(df[0].values, df[1].values)])
   
    # remove unit of exp. values
    df['exp_DDG'] = df['exp. DeltaG [kcal/mol]'].apply(lambda x: x.magnitude)
    df['exp_dDDG'] = df['exp. Error [kcal/mol]'].apply(lambda x: x.magnitude)

    # filter only to relevant columns
    df = df.filter(items = [0,1,'exp_DDG', 'exp_dDDG'])
    df[0]= df[0].astype(str)
    df[1]= df[1].astype(str)
    return df
getExpResults('tnks2')
# Out:
# tnks2_edge_7_5j    7  5j    -2.70       0.0
# tnks2_edge_7_8a    7  8a    -2.42       0.0
# tnks2_edge_5p_5n  5p  5n    -0.21       0.0
# tnks2_edge_1a_5d  1a  5d    -2.35       0.0
# tnks2_edge_8f_5m  8f  5m    -0.89       0.0
# tnks2_edge_8f_8a  8f  8a     1.01       0.0
# tnks2_edge_8a_5d  8a  5d    -0.08       0.0
# tnks2_edge_5o_5m  5o  5m    -0.66       0.0
# tnks2_edge_5d_5m  5d  5m    -1.82       0.0

# %%
author = "hahn"
software = "experiment"

# %%
for target in targets.target_dict:
    df = getExpResults(target)
    if df is None:
        continue
    os.makedirs(os.path.join(path, targets.get_target_dir(target)), exist_ok=True)
    os.makedirs(os.path.join(path, targets.get_target_dir(target), results_dir), exist_ok=True)
    with open(os.path.join(path, targets.get_target_dir(target), results_dir, f'{target}_{software}_{author}.yaml'), 'w') as file:
        df = df.filter([0,1,'exp_DDG', 'exp_dDDG'])
        df.rename(columns={0: 'ligandA', 1: 'ligandB', 'exp_DDG': 'DDG', 'exp_dDDG': 'dDDG'}, inplace=True)
        # set a default error for unknown experimental error of 0.64 kcal/mol
        dddg = np.sqrt(2)*0.28
        print(df['dDDG'])
        df['dDDG'] = df['dDDG'].apply(lambda x: dddg if x < 1e-6 else x)
        print(df['dDDG'])
        df['unit']='kilocalories / mole'
        yaml.dump(df.T.to_dict(), file)
# Out:
# /home/dhahn3/miniconda3/envs/off/lib/python3.7/site-packages/pandas/core/dtypes/cast.py:1638: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
# jnk1_edge_17124-1_18634-1    0.29
# jnk1_edge_18626-1_18624-1    0.21
# jnk1_edge_18636-1_18625-1    0.36
# jnk1_edge_18632-1_18624-1    0.31
# jnk1_edge_18635-1_18625-1    0.18
# jnk1_edge_18626-1_18658-1    0.17
# jnk1_edge_18639-1_18658-1    0.15
# jnk1_edge_18626-1_18625-1    0.21
# jnk1_edge_18638-1_18658-1    0.12
# jnk1_edge_18628-1_18624-1    0.23
# jnk1_edge_18631-1_18660-1    0.24
# jnk1_edge_18638-1_18634-1    0.09
# jnk1_edge_18626-1_18632-1    0.30
# jnk1_edge_18626-1_18630-1    0.14
# jnk1_edge_18631-1_18624-1    0.27
# jnk1_edge_18629-1_18627-1    0.19
# jnk1_edge_18634-1_18637-1    0.27
# jnk1_edge_18626-1_18627-1    0.22
# jnk1_edge_18631-1_18652-1    0.25
# jnk1_edge_18637-1_18631-1    0.35
# jnk1_edge_18626-1_18634-1    0.15
# jnk1_edge_18633-1_18624-1    0.25
# jnk1_edge_17124-1_18631-1    0.37
# jnk1_edge_18627-1_18630-1    0.17
# jnk1_edge_18659-1_18634-1    0.08
# jnk1_edge_18636-1_18624-1    0.35
# jnk1_edge_18626-1_18628-1    0.23
# jnk1_edge_18626-1_18660-1    0.16
# jnk1_edge_18626-1_18659-1    0.16
# jnk1_edge_18639-1_18634-1    0.13
# jnk1_edge_18635-1_18624-1    0.17
# Name: dDDG, dtype: float64
# jnk1_edge_17124-1_18634-1    0.29
# jnk1_edge_18626-1_18624-1    0.21
# jnk1_edge_18636-1_18625-1    0.36
# jnk1_edge_18632-1_18624-1    0.31
# bace_edge_CAT-13g_CAT-17g    0.0
# bace_edge_CAT-13d_CAT-13h    0.0
# bace_edge_CAT-13a_CAT-17i    0.0
# bace_edge_CAT-4m_CAT-13j     0.0
# bace_edge_CAT-13a_CAT-13m    0.0
# bace_edge_CAT-4l_CAT-13k     0.0
# bace_edge_CAT-13o_CAT-17i    0.0
# bace_edge_CAT-4c_CAT-4o      0.0
# bace_edge_CAT-4j_CAT-4o      0.0
# bace_edge_CAT-4i_CAT-13m     0.0
# bace_edge_CAT-24_CAT-17i     0.0
# bace_edge_CAT-13j_CAT-4o     0.0
# bace_edge_CAT-4n_CAT-13k     0.0
# bace_edge_CAT-4o_CAT-4b      0.0
# bace_edge_CAT-17i_CAT-13f    0.0
# bace_edge_CAT-17c_CAT-17e    0.0
# bace_edge_CAT-13k_CAT-4b     0.0
# bace_edge_CAT-4m_CAT-4j      0.0
# bace_edge_CAT-13n_CAT-13k    0.0
# bace_edge_CAT-13d_CAT-17h    0.0
# bace_edge_CAT-17b_CAT-13d    0.0
# bace_edge_CAT-4m_CAT-4n      0.0
# bace_edge_CAT-4m_CAT-13k     0.0
# bace_edge_CAT-13c_CAT-17i    0.0
# bace_edge_CAT-4a_CAT-4o      0.0
# bace_edge_CAT-13h_CAT-17i    0.0
# bace_edge_CAT-4o_CAT-4d      0.0
# bace_edge_CAT-17g_CAT-17c    0.0
# bace_edge_CAT-4a_CAT-13k     0.0
# bace_edge_CAT-13d_CAT-17d    0.0
# bace_edge_CAT-17g_CAT-17f    0.0
# bace_edge_CAT-13e_CAT-17i    0.0
# bace_edge_CAT-13d_CAT-13b    0.0
# bace_edge_CAT-17g_CAT-13i    0.0
# bace_edge_CAT-4m_CAT-13m     0.0
# bace_edge_CAT-17g_CAT-13c    0.0
# bace_edge_CAT-17i_CAT-17a    0.0
# bace_edge_CAT-13d_CAT-13f    0.0
# bace_edge_CAT-17f_CAT-17e    0.0
# bace_edge_CAT-13d_CAT-17a    0.0
# bace_edge_CAT-17g_CAT-17d    0.0
# bace_edge_CAT-13n_CAT-13a    0.0
# bace_edge_CAT-13o_CAT-17h    0.0
# bace_edge_CAT-17b_CAT-17e    0.0
# bace_edge_CAT-4k_CAT-4o      0.0
# bace_edge_CAT-4m_CAT-4l      0.0
# bace_edge_CAT-4m_CAT-4k      0.0
# bace_edge_CAT-13n_CAT-4i     0.0
# bace_edge_CAT-13g_CAT-17i    0.0
# bace_edge_CAT-4p_CAT-13k     0.0
# bace_edge_CAT-4m_CAT-4p      0.0
# bace_edge_CAT-13d_CAT-13i    0.0
# Name: dDDG, dtype: float64
# bace_edge_CAT-13b_CAT-17g    0.39598
# bace_edge_CAT-13a_CAT-17g    0.39598
# bace_edge_CAT-13e_CAT-17g    0.39598
# bace_edge_CAT-4m_CAT-4c      0.39598
# bace_edge_CAT-13k_CAT-4d     0.39598
# bace_edge_CAT-24_CAT-17e     0.39598
# bace_edge_CAT-13g_CAT-17g    0.39598
# bace_edge_CAT-13d_CAT-13h    0.39598
# bace_edge_CAT-13a_CAT-17i    0.39598
# bace_edge_CAT-4m_CAT-13j     0.39598
# bace_edge_CAT-13a_CAT-13m    0.39598
# bace_edge_CAT-4l_CAT-13k     0.39598
# bace_edge_CAT-13o_CAT-17i    0.39598
# bace_edge_CAT-4c_CAT-4o      0.39598
# bace_edge_CAT-4j_CAT-4o      0.39598
# bace_edge_CAT-4i_CAT-13m     0.39598
# bace_edge_CAT-24_CAT-17i     0.39598
# bace_edge_CAT-13j_CAT-4o     0.39598
# bace_edge_CAT-4n_CAT-13k     0.39598
# bace_edge_CAT-4o_CAT-4b      0.39598
# bace_edge_CAT-17i_CAT-13f    0.39598
# bace_edge_CAT-17c_CAT-17e    0.39598
# bace_edge_CAT-13k_CAT-4b     0.39598
# bace_edge_CAT-4m_CAT-4j      0.39598
# bace_edge_CAT-13n_CAT-13k    0.39598
# bace_edge_CAT-13d_CAT-17h    0.39598
# bace_edge_CAT-17b_CAT-13d    0.39598
# bace_edge_CAT-4m_CAT-4n      0.39598
# bace_edge_CAT-4m_CAT-13k     0.39598
# bace_edge_CAT-13c_CAT-17i    0.39598
# bace_edge_CAT-4a_CAT-4o      0.39598
# bace_edge_CAT-13h_CAT-17i    0.39598
# bace_edge_CAT-4o_CAT-4d      0.39598
# bace_edge_CAT-17g_CAT-17c    0.39598
# bace_edge_CAT-4a_CAT-13k     0.39598
# bace_edge_CAT-13d_CAT-17d    0.39598
# bace_edge_CAT-17g_CAT-17f    0.39598
# bace_edge_CAT-13e_CAT-17i    0.39598
# bace_edge_CAT-13d_CAT-13b    0.39598
# bace_edge_CAT-17g_CAT-13i    0.39598
# bace_edge_CAT-4m_CAT-13m     0.39598
# bace_edge_CAT-17g_CAT-13c    0.39598
# bace_edge_CAT-17i_CAT-17a    0.39598
# bace_edge_CAT-13d_CAT-13f    0.39598
# bace_edge_CAT-17f_CAT-17e    0.39598
# bace_edge_CAT-13d_CAT-17a    0.39598
# bace_edge_CAT-17g_CAT-17d    0.39598
# bace_edge_CAT-13n_CAT-13a    0.39598
# bace_edge_CAT-13o_CAT-17h    0.39598
# bace_edge_CAT-17b_CAT-17e    0.39598
# bace_edge_CAT-4k_CAT-4o      0.39598
# bace_edge_CAT-4m_CAT-4l      0.39598
# bace_edge_CAT-4m_CAT-4k      0.39598
# bace_edge_CAT-13n_CAT-4i     0.39598
# bace_edge_CAT-13g_CAT-17i    0.39598
# bace_edge_CAT-4p_CAT-13k     0.39598
# bace_edge_CAT-4m_CAT-4p      0.39598
# bace_edge_CAT-13d_CAT-13i    0.39598
# Name: dDDG, dtype: float64
# bace_hunt_edge_33_13    0.0
# bace_hunt_edge_33_25    0.0
# bace_hunt_edge_31_33    0.0
# bace_hunt_edge_12_33    0.0
# bace_hunt_edge_28_34    0.0
# bace_hunt_edge_28_37    0.0
# bace_hunt_edge_28_23    0.0
# bace_hunt_edge_22_32    0.0
# bace_hunt_edge_22_16    0.0
# bace_hunt_edge_26_32    0.0
# bace_hunt_edge_26_14    0.0
# bace_hunt_edge_16_26    0.0
# bace_hunt_edge_37_34    0.0
# tnks2_edge_8d_1a    0.39598
# tnks2_edge_8d_8f    0.39598
# tnks2_edge_8d_8c    0.39598
# tnks2_edge_5b_5o    0.39598
# tnks2_edge_5b_5n    0.39598
# tnks2_edge_5b_5c    0.39598
# tnks2_edge_5b_5j    0.39598
# tnks2_edge_5h_5m    0.39598
# tnks2_edge_8c_5k    0.39598
# tnks2_edge_5a_5k    0.39598
# tnks2_edge_5a_5j    0.39598
# tnks2_edge_5a_5d    0.39598
# tnks2_edge_5a_5n    0.39598
# tnks2_edge_5a_5c    0.39598
# tnks2_edge_5k_5d    0.39598
# tnks2_edge_7_3b     0.39598
# tnks2_edge_7_5d     0.39598
# tnks2_edge_7_5j     0.39598
# tnks2_edge_7_8a     0.39598
# tnks2_edge_5p_5n    0.39598
# tnks2_edge_1a_5d    0.39598
# tnks2_edge_8f_5m    0.39598
# tnks2_edge_8f_8a    0.39598
# tnks2_edge_8a_5d    0.39598
# tnks2_edge_5o_5m    0.39598
# tnks2_edge_5d_5m    0.39598
# Name: dDDG, dtype: float64

# %% [markdown]
# # pmx calculations with openFF parameters (Hahn et al.)

# %%
# function to retrieve data from PLBenchmarks calculations, soted in 00_data/input 
def getRawResults(target, forcefield='openff-1.0.0.offxml'):
    file_path = os.path.join(path, 
                                   '..', 
                                   '00_data', 
                                   'input',  
                                   f'{target}_{forcefield}.dat'
                                  )
    if not os.path.exists(file_path):
        print(f'File {file_path} does not exist.')
        return
    # read in result file
    res = pd.read_csv(file_path,
                      header=None, 
                      comment='#', 
                      skipinitialspace=True, 
                      names=['edge', 'calc DDG', 'calc dDDG' , 'add dDDG'], 
                      sep=' ')
    res.index = res['edge']
    # read in exp. data
    edg = edges.EdgeSet(target)
    df = edg.get_dataframe(columns=[0,1, 'exp. DeltaG [kcal/mol]', 'exp. Error [kcal/mol]'])
    df.index = pd.Series(['edge_' + str(lig1) + '_' + str(lig2) for lig1, lig2 in zip(df[0].values, df[1].values)])
   
    # copy in calculated values
    df['calc_DDG'] = res.loc[:,'calc DDG']
    df['calc_dDDG'] = res.loc[:,'calc dDDG']
    df['calc_dDDG(additional)'] = res.loc[:, 'add dDDG']
    
    # remove unit of calculated values
    df['exp_DDG'] = df['exp. DeltaG [kcal/mol]'].apply(lambda x: x.magnitude)
    df['exp_dDDG'] = df['exp. Error [kcal/mol]'].apply(lambda x: x.magnitude)

    # filter only to relevant columns
    df = df.filter(items = [0,1,'exp_DDG', 'exp_dDDG', 'calc_DDG', 'calc_dDDG', 'calc_dDDG(additional)'])
    df[0]= df[0].astype(str)
    df[1]= df[1].astype(str)
    df.index = pd.Series([f'{target}_edge_' + str(lig1) + '_' + str(lig2) for lig1, lig2 in zip(df[0].values, df[1].values)])
    return df
getRawResults('cmet')
# Out:
#                                                                                    0  \
# cmet_edge_CHEMBL3402741_400_CHEMBL3402756_2.7                      CHEMBL3402741_400
# cmet_edge_CHEMBL3402741_400_CHEMBL3402763_90                       CHEMBL3402741_400
# cmet_edge_CHEMBL3402741_400_CHEMBL3402764_90                       CHEMBL3402741_400
# cmet_edge_CHEMBL3402742_23_CHEMBL3402756_2.7                        CHEMBL3402742_23
# cmet_edge_CHEMBL3402742_23_CHEMBL3402763_90                         CHEMBL3402742_23
# cmet_edge_CHEMBL3402743_42_CHEMBL3402742_23                         CHEMBL3402743_42
# cmet_edge_CHEMBL3402743_42_CHEMBL3402756_2.7                        CHEMBL3402743_42
# cmet_edge_CHEMBL3402743_42_CHEMBL3402758_10                         CHEMBL3402743_42
# cmet_edge_CHEMBL3402743_42_CHEMBL3402760_
# cmet_edge_CHEMBL3402759_5.7_CHEMBL3402757_6.5          -0.93       0.27
# cmet_edge_CHEMBL3402759_5.7_CHEMBL3402758_10           -0.85       0.33
# cmet_edge_CHEMBL3402759_5.7_CHEMBL3402763_90            0.54       0.44
# cmet_edge_CHEMBL3402761_1_21_CHEMBL3402754_40_14        2.57       0.48
# cmet_edge_CHEMBL3402761_1_21_CHEMBL3402755_4200_15      3.55       0.21
# cmet_edge_CHEMBL3402761_1_21_CHEMBL3402760_1           -1.82       0.65
# cmet_edge_CHEMBL3402761_1_21_CHEMBL3402762_1            0.25       0.72
# cmet_edge_CHEMBL3402762_1_CHEMBL3402760_1               1.39       0.42
# cmet_edge_CHEMBL3402763_90_CHEMBL3402764_90             1.67       0.17
# cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEM...     -0.22       0.29
# cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEM...      0.22       0.91
# cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEM...      3.43       0.43
# cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEM...      1.49       0.46
# cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEM...     -3.58       0.77
# cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEM...      0.12       0.82
#
#                                                     calc_dDDG(additional)
# cmet_edge_CHEMBL3402741_400_CHEMBL3402756_2.7                         NaN
# cmet_edge_CHEMBL3402741_400_CHEMBL3402763_90                          NaN
# cmet_edge_CHEMBL3402741_400_CHEMBL3402764_90                          NaN
# cmet_edge_CHEMBL3402742_23_CHEMBL3402756_2.7                          NaN
# cmet_edge_CHEMBL3402742_23_CHEMBL3402763_90                           NaN
# cmet_edge_CHEMBL3402743_42_CHEMBL3402742_23                           NaN
# cmet_edge_CHEMBL3402743_42_CHEMBL3402756_2.7                          NaN
# cmet_edge_CHEMBL3402743_42_CHEMBL3402758_10                           NaN
# cmet_edge_CHEMBL3402743_42_CHEMBL3402760_1                            NaN
# cmet_edge_CHEMBL3402743_42_CHEMBL3402762_1                            NaN
# cmet_edge_CHEMBL3402743_42_CHEMBL3402763_90                           NaN
# cmet_edge_CHEMBL3402743_42_CHEMBL3402764_90                           NaN
# cmet_edge_CHEMBL3402744_300_4_CHEMBL3402745_200_5                     NaN
# cmet_edge_CHEMBL3402744_300_4_CHEMBL3402752_300...                    NaN
# cmet_edge_CHEMBL3402744_300_4_CHEMBL3402756_2.7                       NaN
# cmet_edge_CHEMBL3402744_300_4_CHEMBL3402757_6.5                       NaN
# cmet_edge_CHEMBL3402745_200_5_CHEMBL3402742_23                        NaN
# cmet_edge_CHEMBL3402745_200_5_CHEMBL3402743_42                        NaN
# cmet_edge_CHEMBL3402745_200_5_CHEMBL3402748_5300_8                    NaN
# cmet_edge_CHEMBL3402745_200_5_CHEMBL3402752_300...                    NaN
# cmet_edge_CHEMBL3402745_200_5_CHEMBL3402756_2.7                       NaN
# cmet_edge_CHEMBL3402747_3400_7_CHEMBL3402744_300_4                    NaN
# cmet_edge_CHEMBL3402747_3400_7_CHEMBL3402749_500_9                    NaN
# cmet_edge_CHEMBL3402747_3400_7_CHEMBL3402751_21...                    NaN
# cmet_edge_CHEMBL3402747_3400_7_CHEMBL3402752_30...                    NaN
# cmet_edge_CHEMBL3402747_3400_7_CHEMBL3402755_42...                    NaN
# cmet_edge_CHEMBL3402748_5300_8_CHEMBL3402751_21...                    NaN
# cmet_edge_CHEMBL3402749_500_9_CHEMBL3402748_5300_8                    NaN
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402748_53...                    NaN
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402749_500_9                    NaN
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402751_21...                    NaN
# cmet_edge_CHEMBL3402752_30000_12_CHEMBL3402751_...                    NaN
# cmet_edge_CHEMBL3402752_30000_12_CHEMBL3402754_...                    NaN
# cmet_edge_CHEMBL3402753_200_13_CHEMBL3402747_34...                    NaN
# cmet_edge_CHEMBL3402753_200_13_CHEMBL3402750_40...                    NaN
# cmet_edge_CHEMBL3402753_200_13_CHEMBL3402755_42...                    NaN
# cmet_edge_CHEMBL3402753_200_13_CHEMBL3402761_1_21                     NaN
# cmet_edge_CHEMBL3402755_4200_15_CHEMBL3402754_4...                    NaN
# cmet_edge_CHEMBL3402757_6.5_CHEMBL3402756_2.7                         NaN
# cmet_edge_CHEMBL3402758_10_CHEMBL3402742_23                           NaN
# cmet_edge_CHEMBL3402758_10_CHEMBL3402756_2.7                          NaN
# cmet_edge_CHEMBL3402758_10_CHEMBL3402760_1                            NaN
# cmet_edge_CHEMBL3402759_5.7_CHEMBL3402757_6.5                         NaN
# cmet_edge_CHEMBL3402759_5.7_CHEMBL3402758_10                          NaN
# cmet_edge_CHEMBL3402759_5.7_CHEMBL3402763_90                          NaN
# cmet_edge_CHEMBL3402761_1_21_CHEMBL3402754_40_14                      NaN
# cmet_edge_CHEMBL3402761_1_21_CHEMBL3402755_4200_15                    NaN
# cmet_edge_CHEMBL3402761_1_21_CHEMBL3402760_1                          NaN
# cmet_edge_CHEMBL3402761_1_21_CHEMBL3402762_1                          NaN
# cmet_edge_CHEMBL3402762_1_CHEMBL3402760_1                             NaN
# cmet_edge_CHEMBL3402763_90_CHEMBL3402764_90                           NaN
# cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEM...                    NaN
# cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEM...                    NaN
# cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEM...                    NaN
# cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEM...                    NaN
# cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEM...                    NaN
# cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEM...                    NaN

# %%
author = "hahn"
software = "pmx"
forcefield = "openff-1.0.0.offxml"

# %%
for target in targets.target_dict:
    df = getRawResults(target, forcefield)
    if df is None:
        continue
    os.makedirs(os.path.join(path, targets.get_target_dir(target), results_dir), exist_ok=True)
    with open(os.path.join(path, targets.get_target_dir(target), results_dir, f'{target}_{software}_{forcefield}_{author}.yaml'), 'w') as file:
        df = df.filter([0,1,'calc_DDG', 'calc_dDDG'])
        df.rename(columns={0: 'ligandA', 1: 'ligandB', 'calc_DDG': 'DDG', 'calc_dDDG': 'dDDG'}, inplace=True)
        df['unit']='kilocalories / mole'
        yaml.dump(df.T.to_dict(), file)

# %% [markdown]
# ## Gather data from Activity Cliffs, Perez-Benito et al.

# %%
target="ros1"
file_name = f'{path}/../00_data/input/{target}_opls3e.csv'
if not os.path.exists(file_name):
    print(f'File {file_name} does not exist.')
data = pd.read_csv(file_name, header=0, comment='#')
print(data)
data['Ligand1'] = data['Ligand1'].astype(str)
# data['Ligand1'] = [x.split('_')[1] for x in data['Ligand1']]
data['Ligand2'] = data['Ligand2'].astype(str)
# data['Ligand2'] = [x.split('_')[1] for x in data['Ligand2']]
data['edge'] = pd.Series([f'{target}_edge_{a.split("_")[1]}_{b.split("_")[1]}' for a, b in zip(data['Ligand1'].values, data['Ligand2'].values)])
data.index=data['edge']
data.drop(columns='edge', inplace=True)
print(data)
for e, edg in edges.EdgeSet(target).items():
    if f'{target}_{e}' not in data.index:
        print(e)
        edg_dict = edg.get_dict()
#         print(edg_dict)
        n_index = f'{target}_edge_{e.split("_")[2]}_{e.split("_")[1]}'
        if n_index in data.index:
            row = data.loc[n_index, :]
            n_row = pd.Series({"Ligand1": row["Ligand2"],
                               "Ligand2": row["Ligand1"],
                                "edge": e,
                               "FEP": -row["FEP"],
                               "FEP Error": row["FEP Error"]
                              }
                                  )
            data.loc[e,:] = n_row
            data.drop(n_index, inplace=True)
        else:
            print(e)
data.to_csv('tmp.csv', sep=',', columns=["Ligand1", "Ligand2", "FEP", "FEP Error"], index=None)
# Out:
#      Ligand1   Ligand2   FEP  FEP Error
# 0   lig_0681  lig_1537  0.92       0.06
# 1   lig_0681  lig_1872 -0.47       0.06
# 2   lig_0681  lig_5109  1.60       0.15
# 3   lig_0681  lig_7454  1.14       0.09
# 4   lig_1537  lig_0529 -2.12       0.07
# ..       ...       ...   ...        ...
# 57  lig_1872  lig_6770  2.57       0.24
# 58  lig_3507  lig_6770  0.53       0.25
# 59  lig_5602  lig_7454  2.09       0.20
# 60  lig_6674  lig_6770  1.95       0.23
# 61  lig_6770  lig_8550 -1.68       0.29
#
# [62 rows x 4 columns]
#                       Ligand1   Ligand2   FEP  FEP Error
# edge
# ros1_edge_0681_1537  lig_0681  lig_1537  0.92       0.06
# ros1_edge_0681_1872  lig_0681  lig_1872 -0.47       0.06
# ros1_edge_0681_5109  lig_0681  lig_5109  1.60       0.15
# ros1_edge_0681_7454  lig_0681  lig_7454  1.14       0.09
# ros1_edge_1537_0529  lig_1537  lig_0529 -2.12       0.07
# ...                       ...       ...   ...        ...
# ros1_edge_1872_6770  lig_1872  lig_6770  2.57       0.24
# ros1_edge_3507_6770  lig_3507  lig_6770  0.53       0.25
# ros1_edge_5602_7454  lig_5602  lig_7454  2.09       0.20
# ros1_edge_6674_6770  lig_6674  lig_6770  1.95       0.23
# ros1_edge_6770_8550  lig_6770  lig_8550 -1.68       0.29
#
# [62 rows x 4 columns]

# %%
def get_perez_results(target):  
    file_name = f'{path}/../00_data/input/{target}_opls3e.csv'
    if not os.path.exists(file_name):
        print(f'File {file_name} does not exist.')
        return None
    data = pd.read_csv(file_name, header=0, comment='#')
    data['Ligand1'] = data['Ligand1'].astype(str)
    data['Ligand1'] = [x.split('_')[1] for x in data['Ligand1']]
    data['Ligand2'] = data['Ligand2'].astype(str)
    data['Ligand2'] = [x.split('_')[1] for x in data['Ligand2']]
    data['edge'] = pd.Series([f'{target}_edge_{a}_{b}' for a, b in zip(data['Ligand1'].values, data['Ligand2'].values)])
    data.index=data['edge']
    data.drop(columns='edge', inplace=True)
    return data

# %%
author = "perez"
for target in ['ros1', 'pde10']:
    df = get_perez_results(target)
    if df is None:
        continue
    os.makedirs(os.path.join(path, targets.get_target_dir(target), results_dir), exist_ok=True)
    forcefield = 'opls3e'
    software = 'fep+'
    unit = 'kilocalories / mole'
    print(df)
    df.rename(columns={'Ligand1': 'ligandA', 'Ligand2': 'ligandB', f'FEP': 'DDG', f'FEP Error': 'dDDG'}, inplace=True)
    df['unit'] = unit
    if forcefield.startswith('fep'):
        forcefield = f'opls3e_{forcefield[-1]}'
    with open(os.path.join(path, targets.get_target_dir(target), results_dir, f'{target}_{software}_{forcefield}_{author}.yaml'), 'w') as file:
# %%
def getGapsysResults(target):  
    file_name = f'{temp_directory}/protLig_benchmark/ddg_data/{target}.dat'
    print(file_name)
    if not os.path.exists(file_name):
        print(f'File {file_name} does not exist.')
        return None
    data = pd.read_csv(f'{temp_directory}/protLig_benchmark/ddg_data/{target}.dat', sep='\s+', header=None, comment='#',
                   names=['edge', 'exp', 'gaff', 'dgaff', 'cgenff', 'dcgenff', 'cons', 'dcons', 'fep5', 'dfep5', 'fep1', 'dfep1'])
    data['dexp']=pd.Series([0.0]*data.shape[0])
    df = edges.EdgeSet(target).get_dataframe()
    if target == 'jnk1':
        df.index = pd.Series([f'{str(a).split("-")[0]}_{str(b).split("-")[0]}' for a, b in zip(df[0].values, df[1].values)])
    else:
        df.index = pd.Series([f'{a}_{b}' for a, b in zip(df[0].values, df[1].values)])
    newdata = data.copy()
    print(newdata['edge'], df.index)
    newdata.index=newdata['edge']

    newdata.columns = pd.MultiIndex.from_arrays([np.array(newdata.columns), ['', 'exp'] + ['pmx'] * 6 + ['fep'] * 4 + ['exp'], [''] + ['kj/mol'] * 12], names=['forcefield', 'method', 'unit'])
    
    newdata.loc[:,('ligandA', '', '')] = df[0].apply(lambda x: str(int(float(x))) if str(x).endswith('.0') else x).astype(str)
    newdata.loc[:,('ligandB', '', '')] = df[1].apply(lambda x: str(int(float(x))) if str(x).endswith('.0') else x).astype(str)
    newdata = newdata.drop(columns=('edge', '', ''))
    newdata.sort_index(axis=1, level=1, inplace=True, sort_remaining=False)
    newdata.index=[f'{target}_edge_{x[("ligandA", "", "")]}_{x[("ligandB", "", "")]}' for i, x in newdata.iterrows()]
    
    return newdata
getGapsysResults('cmet')
# Out:
# /tmp/tmpiqftyrw2/protLig_benchmark/ddg_data/cmet.dat
# /home/dhahn3/miniconda3/envs/off/lib/python3.7/site-packages/pandas/core/dtypes/cast.py:1638: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
# 0          CHEMBL3402744_300_4_CHEMBL3402745_200_5
# 1         CHEMBL3402747_3400_7_CHEMBL3402745_200_5
# 2        CHEMBL3402747_3400_7_CHEMBL3402748_5300_8
# 3       CHEMBL3402747_3400_7_CHEMBL3402751_2100_11
# 4       CHEMBL3402748_5300_8_CHEMBL3402751_2100_11
# 5         CHEMBL3402749_500_9_CHEMBL3402747_3400_7
# 6         CHEMBL3402749_500_9_CHEMBL3402748_5300_8
# 7        CHEMBL3402749_500_9_CHEMBL3402751_2100_11
# 8          CHEMBL3402749_500_9_CHEMBL3402754_40_14
# 9        CHEMBL3402750_400_10_CHEMBL3402747_3400_7
# 10       CHEMBL3402750_400_10_CHEMBL3402748_5300_8
# 11        CHEMBL3402750_400_10_CHEMBL3402749_500_9
# 12      CHEMBL3402752_30000_12_CHEMBL3402744_300_4
# 13     CHEMBL3402752_30000_12_CHEMBL3402747_3400_7
# 14     CHEMBL3402752_30000_12_CHEMBL3402748_5300_8
# 15      CHEMBL3402752_30000_12_CHEMBL3402749_500_9
# 16      CHEMBL3402752_30000_12_CHEMBL3402754_40_14
# 17    CHEMBL3402752_30000_12_CHEMBL3402755_4200_15
# 18       CHEMBL3402753_200_13_CHEMBL3402748_5300_8
# 19        CHEMBL3402753_200_13_CHEMBL3402754_40_14
# 20       CHEMBL3402754_40_14_CHEMBL3402751_2100_11
#        'CHEMBL3402759_5.7_CHEMBL3402763_90',
#        'CHEMBL3402761_1_21_CHEMBL3402754_40_14',
#        'CHEMBL3402761_1_21_CHEMBL3402755_4200_15',
#        'CHEMBL3402761_1_21_CHEMBL3402760_1',
#        'CHEMBL3402761_1_21_CHEMBL3402762_1', 'CHEMBL3402762_1_CHEMBL3402760_1',
#        'CHEMBL3402763_90_CHEMBL3402764_90',
#        'CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402742_23',
#        'CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402743_42',
#        'CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402744_300_4',
#        'CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402745_200_5',
#        'CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402760_1',
#        'CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402764_90'],
#       dtype='object')
# forcefield                                                         ligandA  \
# method
# unit
# cmet_edge_CHEMBL3402744_300_4_CHEMBL3402745_200_5      CHEMBL3402744_300_4
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_CHEMBL3402747_3400_7_CHEMBL3402751_21...    CHEMBL3402747_3400_7
# cmet_edge_CHEMBL3402748_5300_8_CHEMBL3402751_21...    CHEMBL3402748_5300_8
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_CHEMBL3402749_500_9_CHEMBL3402748_5300_8     CHEMBL3402749_500_9
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402748_53...    CHEMBL3402750_400_10
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402749_500_9    CHEMBL3402750_400_10
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_CHEMBL3402752_30000_12_CHEMBL3402754_...  CHEMBL3402752_30000_12
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_nan_nan                                                      NaN
# cmet_edge_CHEMBL3402755_4200_15_CHEMBL3402754_4...   CHEMBL3402755_4200_15
# cmet_edge_nan_nan                                                      NaN
#
# forcefield                                                        ligandB  \
# method
# unit
# cmet_edge_CHEMBL3402744_300_4_CHEMBL3402745_200_5     CHEMBL3402745_200_5
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_CHEMBL3402747_3400_7_CHEMBL3402751_21...  CHEMBL3402751_2100_11
# cmet_edge_CHEMBL3402748_5300_8_CHEMBL3402751_21...  CHEMBL3402751_2100_11
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_CHEMBL3402749_500_9_CHEMBL3402748_5300_8   CHEMBL3402748_5300_8
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402748_53...   CHEMBL3402748_5300_8
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402749_500_9    CHEMBL3402749_500_9
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_CHEMBL3402752_30000_12_CHEMBL3402754_...    CHEMBL3402754_40_14
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_nan_nan                                                     NaN
# cmet_edge_CHEMBL3402755_4200_15_CHEMBL3402754_4...    CHEMBL3402754_40_14
# cmet_edge_nan_nan                                                     NaN
#
# forcefield                                            exp   dexp   fep5  \
# method                                                exp    exp    fep
# unit                                               kj/mol kj/mol kj/mol
# cmet_edge_CHEMBL3402744_300_4_CHEMBL3402745_200_5   -1.01    0.0  -3.24
# cmet_edge_nan_nan                                   -7.02    0.0  -6.33
# cmet_edge_nan_nan                                    1.10    0.0   6.19
# cmet_edge_CHEMBL3402747_3400_7_CHEMBL3402751_21...  -1.19    0.0  -2.40
# cmet_edge_CHEMBL3402748_5300_8_CHEMBL3402751_21...  -2.29    0.0  -9.22
# cmet_edge_nan_nan                                    4.75    0.0   4.97
# cmet_edge_CHEMBL3402749_500_9_CHEMBL3402748_5300_8   5.85    0.0  11.39
# cmet_edge_nan_nan                                    3.56    0.0   2.26
# cmet_edge_nan_nan                                   -6.26    0.0  -9.97
# cmet_edge_nan_nan                                    5.31    0.0   8.35
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402748_53...   6.41    0.0  15.06
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402749_500_9   0.55    0.0   4.27
# cmet_edge_nan_nan                                  -11.42    0.0  -5.01
# cmet_edge_nan_nan                                   -5.40    0.0  -2.22
# cmet_edge_nan_nan                                   -4.30    0.0   6.51
# cmet_edge_nan_nan                                  -10.15    0.0  -6.36
# cmet_edge_CHEMBL3402752_30000_12_CHEMBL3402754_... -16.41    0.0 -15.65
# cmet_edge_nan_nan                                   -4.87    0.0  -5.26
# cmet_edge_nan_nan                                    8.12    0.0  14.46
# cmet_edge_nan_nan                                   -3.99    0.0  -5.56
# cmet_edge_nan_nan                                    9.82    0.0  10.81
# cmet_edge_nan_nan                                   -9.14    0.0  -8.77
# cmet_edge_nan_nan                                   -7.55    0.0  -5.22
# cmet_edge_CHEMBL3402755_4200_15_CHEMBL3402754_4... -11.54    0.0 -11.31
# cmet_edge_nan_nan                                  -20.68    0.0 -21.25
#
# forcefield                                          dfep5   fep1  dfep1  \
# method                                                fep    fep    fep
# unit                                               kj/mol kj/mol kj/mol
# cmet_edge_CHEMBL3402744_300_4_CHEMBL3402745_200_5    0.27  -3.58   0.68
# cmet_edge_nan_nan                                    0.49  -5.01   0.89
# cmet_edge_nan_nan                                    0.40   4.97   0.39
# cmet_edge_CHEMBL3402747_3400_7_CHEMBL3402751_21...   0.64  -5.43   0.41
# cmet_edge_CHEMBL3402748_5300_8_CHEMBL3402751_21...   0.99 -10.00   0.46
# cmet_edge_nan_nan                                    0.96   5.08   1.53
# cmet_edge_CHEMBL3402749_500_9_CHEMBL3402748_5300_8   0.75  10.78   0.82
# cmet_edge_nan_nan                                    0.76   1.19   1.11
# cmet_edge_nan_nan                                    0.33 -11.73   0.88
# cmet_edge_nan_nan                                    0.22  10.47   0.87
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402748_53...   0.40  13.65   0.54
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402749_500_9   0.27   5.47   0.66
# cmet_edge_nan_nan                                    0.81  -5.58   1.41
# cmet_edge_nan_nan                                    0.54  -0.36   0.59
# cmet_edge_nan_nan                                    0.25   7.43   0.94
# cmet_edge_nan_nan                                    0.42  -4.95   0.52
# cmet_edge_CHEMBL3402752_30000_12_CHEMBL3402754_...   0.44 -14.46   0.93
# cmet_edge_nan_nan                                    0.28  -6.33   1.03
# cmet_edge_nan_nan                                    0.46  16.57   0.82
# cmet_edge_nan_nan                                    0.22  -5.58   0.55
# cmet_edge_nan_nan                                    0.32  12.15   0.85
# cmet_edge_nan_nan                                    0.49  -7.31   1.18
# cmet_edge_nan_nan                                    0.20  -4.57   0.32
# cmet_edge_CHEMBL3402755_4200_15_CHEMBL3402754_4...   0.49 -11.45   0.76
# cmet_edge_nan_nan                                    0.50 -17.22   1.49
#
# forcefield                                           gaff  dgaff cgenff  \
# method                                                pmx    pmx    pmx
# unit                                               kj/mol kj/mol kj/mol
# cmet_edge_CHEMBL3402744_300_4_CHEMBL3402745_200_5   -3.43   0.40  -2.34
# cmet_edge_nan_nan                                   -6.85   2.33 -18.11
# cmet_edge_nan_nan                                    3.86   0.91  -6.37
# cmet_edge_CHEMBL3402747_3400_7_CHEMBL3402751_21...  -1.06   0.83  -0.73
# cmet_edge_CHEMBL3402748_5300_8_CHEMBL3402751_21...  -4.83   0.22   2.57
# cmet_edge_nan_nan                                    1.94   0.60   7.30
# cmet_edge_CHEMBL3402749_500_9_CHEMBL3402748_5300_8  19.71   0.71   9.58
# cmet_edge_nan_nan                                    2.82   0.70   6.59
# cmet_edge_nan_nan                                   -6.58   0.95  -5.82
# cmet_edge_nan_nan                                    5.81   0.25   4.14
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402748_53...  21.83   1.42   6.00
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402749_500_9   4.42   0.23   0.29
# cmet_edge_nan_nan                                   -2.52   2.63 -10.15
# cmet_edge_nan_nan                                   -0.82   0.52   5.55
# cmet_edge_nan_nan                                    2.39   0.32   0.25
# cmet_edge_nan_nan                                   -9.80   1.12 -10.99
# cmet_edge_CHEMBL3402752_30000_12_CHEMBL3402754_... -19.34   0.97  -9.75
# cmet_edge_nan_nan                                  -15.19   0.30  -0.46
# cmet_edge_nan_nan                                   21.00   4.16  10.62
# cmet_edge_nan_nan                                  -13.43   0.85 -10.64
# cmet_edge_nan_nan                                   15.33   1.07  15.55
# cmet_edge_nan_nan                                   -5.05   2.83  -2.87
# cmet_edge_nan_nan                                   -1.25   1.02  -8.49
# cmet_edge_CHEMBL3402755_4200_15_CHEMBL3402754_4...  -3.62   1.12 -13.42
# cmet_edge_nan_nan                                   -7.25   2.46 -15.70
#
# forcefield                                         dcgenff   cons  dcons
# method                                                 pmx    pmx    pmx
# unit                                                kj/mol kj/mol kj/mol
# cmet_edge_CHEMBL3402744_300_4_CHEMBL3402745_200_5     0.41  -2.88   0.56
# cmet_edge_nan_nan                                     1.66 -12.48   5.62
# cmet_edge_nan_nan                                     1.36  -1.25   5.11
# cmet_edge_CHEMBL3402747_3400_7_CHEMBL3402751_21...    1.16  -0.90   0.57
# cmet_edge_CHEMBL3402748_5300_8_CHEMBL3402751_21...    0.59  -1.13   3.69
# cmet_edge_nan_nan                                     1.19   4.62   2.65
# cmet_edge_CHEMBL3402749_500_9_CHEMBL3402748_5300_8    2.21  14.64   5.06
# cmet_edge_nan_nan                                     1.83   4.70   1.94
# cmet_edge_nan_nan                                     1.18  -6.20   0.65
# cmet_edge_nan_nan                                     1.03   4.98   0.85
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402748_53...    5.14  13.91   7.76
# cmet_edge_CHEMBL3402750_400_10_CHEMBL3402749_500_9    0.24   2.36   2.06
# cmet_edge_nan_nan                                     1.15  -6.34   3.77
# cmet_edge_nan_nan                                     0.32   2.36   3.18
# cmet_edge_nan_nan                                     0.18   1.32   1.07
# cmet_edge_nan_nan                                     0.71 -10.39   0.73
# cmet_edge_CHEMBL3402752_30000_12_CHEMBL3402754_...    0.67 -14.54   4.79
# cmet_edge_nan_nan                                     0.72  -7.83   7.36
# cmet_edge_nan_nan                                     0.28  15.81   5.24
# cmet_edge_nan_nan                                     3.27 -12.03   1.80
# cmet_edge_nan_nan                                     1.11  15.44   0.63
# cmet_edge_nan_nan                                     1.14  -3.96   1.58
# cmet_edge_nan_nan                                     1.09  -4.87   3.60
# cmet_edge_CHEMBL3402755_4200_15_CHEMBL3402754_4...    1.51  -8.52   4.90
# cmet_edge_nan_nan                                     3.04 -11.47   4.15

# %%
def getGapsysSingleRepeatsResults(target, ff):
    file_name = f'{temp_directory}/protLig_benchmark/dg_data_allRepeats/{target}_{ff}_protein.dat'
    print(file_name)
    if not os.path.exists(file_name):
        print(f'File {file_name} does not exist.')
        return None
    data_complex = pd.read_csv(file_name, sep='\s+', header=None, comment='#',
                   names=['edge', 'dgcomplex1', 'e_dgcomplex1', 'dgcomplex2', 'e_dgcomplex2', 'dgcomplex3', 'e_dgcomplex3'])
    data_complex.index=data_complex['edge']
    file_name = f'{temp_directory}/protLig_benchmark/dg_data_allRepeats/{target}_{ff}_water.dat'
    print(file_name)
    if not os.path.exists(file_name):
        print(f'File {file_name} does not exist.')
        return None
    data_water = pd.read_csv(file_name, sep='\s+', header=None, comment='#',
                   names=['edge', 'dgwater1', 'e_dgwater1', 'dgwater2', 'e_dgwater2', 'dgwater3', 'e_dgwater3'])
    data_water.index=data_water['edge']
   # data['dexp']=pd.Series([0.0]*data.shape[0])
    df = edges.EdgeSet(target).get_dataframe()
    if target == 'jnk1':
        df.index = pd.Series([f'{str(a).split("-")[0]}_{str(b).split("-")[0]}' for a, b in zip(df[0].values, df[1].values)])
    else:
        df.index = pd.Series([f'{a}_{b}' for a, b in zip(df[0].values, df[1].values)])

    d = []
    for edge, row in df.iterrows():
        print(row)
        nedge=edge
#         print(edge, data_water.index)
#         if target=='cmet':
#             for key, item in cmet_dict.items():
#                 nedge=nedge.replace(key, item)
        if nedge not in data_water.index:
            continue
        for i in range(1,4):
            wc='water'
            d.append(
                dict(
                val=unit_registry.Quantity(
                    data_water.loc[nedge,f'dg{wc}{i}'], 'kilojoules / mole'
                ).to('kilocalories / mole').magnitude,
                err= unit_registry.Quantity(
                    data_water.loc[nedge,f'e_dg{wc}{i}'], 'kilojoules / mole'
                ).to('kilocalories / mole').magnitude,
                aerr= np.nan,
                conv=np.nan,
                env=wc,
                repeat=i,
                target=target,
                edge=f'edge_{row[0]}_{row[1]}',
                failed='False'
                )
            )

            wc='complex'
            d.append(
                dict(
                val=unit_registry.Quantity(
                    data_complex.loc[nedge,f'dg{wc}{i}'], 'kilojoules / mole'
                ).to('kilocalories / mole').magnitude,
                err= unit_registry.Quantity(
                    data_complex.loc[nedge,f'e_dg{wc}{i}'], 'kilojoules / mole'
                ).to('kilocalories / mole').magnitude,
                aerr= np.nan,
                conv=np.nan,
                env=wc,
                repeat=i,
                target=target,
                edge=f'edge_{row[0]}_{row[1]}',
                failed='False'
                )
            )

    newdata=pd.DataFrame(d)    
#     newdata.columns = pd.MultiIndex.from_arrays([np.array(newdata.columns), ['', 'exp'] + ['pmx'] * 6 + ['fep'] * 4 + ['exp'], [''] + ['kj/mol'] * 12], names=['forcefield', 'method', 'unit'])
    
#     newdata.loc[:,('ligandA', '', '')] = df[0].apply(lambda x: str(int(float(x))) if str(x).endswith('.0') else x).astype(str)
#     newdata.loc[:,('ligandB', '', '')] = df[1].apply(lambda x: str(int(float(x))) if str(x).endswith('.0') else x).astype(str)
#     newdata = newdata.drop(columns=('edge', '', ''))
#     newdata.sort_index(axis=1, level=1, inplace=True, sort_remaining=False)
#     newdata.index=[f'{target}_edge_{x[("ligandA", "", "")]}_{x[("ligandB", "", "")]}' for i, x in newdata.iterrows()]
    
    return newdata
getGapsysSingleRepeatsResults('cmet', 'cgenff')
# Out:
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/cmet_cgenff_protein.dat
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/cmet_cgenff_water.dat
# 0                                                         CHEMBL3402741_400
# 1                                                         CHEMBL3402756_2.7
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                             -2.98 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402741_400_CHEMBL3402756_2.7, dtype: object
# 0                                                         CHEMBL3402741_400
# 1                                                          CHEMBL3402763_90
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# Smiles2                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# exp. DeltaG [kcal/mol]                             -0.89 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402741_400_CHEMBL3402763_90, dtype: object
# 0                                                         CHEMBL3402741_400
# 1                                                          CHEMBL3402764_90
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                             -0.89 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402741_400_CHEMBL3402764_90, dtype: object
# 0                                                          CHEMBL3402742_23
# 1                                                         CHEMBL3402756_2.7
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                             -1.27 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402742_23_CHEMBL3402756_2.7, dtype: object
# 0                                                          CHEMBL3402742_23
# 1                                                          CHEMBL3402763_90
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# Smiles2                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# exp. DeltaG [kcal/mol]                              0.82 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402742_23_CHEMBL3402763_90, dtype: object
# 0                                                          CHEMBL3402743_42
# 1                                                          CHEMBL3402742_23
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# exp. DeltaG [kcal/mol]                             -0.36 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402743_42_CHEMBL3402742_23, dtype: object
# 0                                                          CHEMBL3402743_42
# 1                                                         CHEMBL3402756_2.7
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                             -1.63 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402743_42_CHEMBL3402756_2.7, dtype: object
# 0                                                          CHEMBL3402743_42
# 1                                                          CHEMBL3402758_10
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[n][c]([H]...
# exp. DeltaG [kcal/mol]                             -0.85 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402743_42_CHEMBL3402758_10, dtype: object
# 0                                                          CHEMBL3402743_42
# 1                                                           CHEMBL3402760_1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                             -2.22 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402743_42_CHEMBL3402760_1, dtype: object
# 0                                                          CHEMBL3402743_42
# 1                                                           CHEMBL3402762_1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                             -2.22 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402743_42_CHEMBL3402762_1, dtype: object
# 0                                                          CHEMBL3402743_42
# 1                                                          CHEMBL3402763_90
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# exp. DeltaG [kcal/mol]                              0.46 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402743_42_CHEMBL3402763_90, dtype: object
# 0                                                          CHEMBL3402743_42
# 1                                                          CHEMBL3402764_90
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                              0.46 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402743_42_CHEMBL3402764_90, dtype: object
# 0                                                       CHEMBL3402744_300_4
# 1                                                       CHEMBL3402745_200_5
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                             -0.25 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402744_300_4_CHEMBL3402745_200_5, dtype: object
# 0                                                       CHEMBL3402744_300_4
# 1                                                    CHEMBL3402752_30000_12
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([c]2[c]([H])[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                              2.74 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402744_300_4_CHEMBL3402752_30000_12, dtype: object
# 0                                                       CHEMBL3402744_300_4
# 1                                                         CHEMBL3402756_2.7
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                             -2.81 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402744_300_4_CHEMBL3402756_2.7, dtype: object
# 0                                                       CHEMBL3402744_300_4
# 1                                                         CHEMBL3402757_6.5
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                             -2.29 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402744_300_4_CHEMBL3402757_6.5, dtype: object
# 0                                                       CHEMBL3402745_200_5
# 1                                                          CHEMBL3402742_23
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# exp. DeltaG [kcal/mol]                             -1.29 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402745_200_5_CHEMBL3402742_23, dtype: object
# 0                                                       CHEMBL3402745_200_5
# 1                                                          CHEMBL3402743_42
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                             -0.93 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402745_200_5_CHEMBL3402743_42, dtype: object
# 0                                                       CHEMBL3402745_200_5
# 1                                                      CHEMBL3402748_5300_8
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([C]([H])([H])[H])[N]([H])[C]([...
# exp. DeltaG [kcal/mol]                              1.96 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402745_200_5_CHEMBL3402748_5300_8, dtype: object
# 0                                                       CHEMBL3402745_200_5
# 1                                                    CHEMBL3402752_30000_12
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([c]2[c]([H])[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                              2.99 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402745_200_5_CHEMBL3402752_30000_12, dtype: object
# 0                                                       CHEMBL3402745_200_5
# 1                                                         CHEMBL3402756_2.7
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                             -2.56 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402745_200_5_CHEMBL3402756_2.7, dtype: object
# 0                                                      CHEMBL3402747_3400_7
# 1                                                       CHEMBL3402744_300_4
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                             -1.44 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402747_3400_7_CHEMBL3402744_300_4, dtype: object
# 0                                                      CHEMBL3402747_3400_7
# 1                                                       CHEMBL3402749_500_9
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([C]([H])([H])[H])[O][C]([c]2[c...
# exp. DeltaG [kcal/mol]                             -1.14 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402747_3400_7_CHEMBL3402749_500_9, dtype: object
# 0                                                      CHEMBL3402747_3400_7
# 1                                                     CHEMBL3402751_2100_11
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([C]([H])([H])[H])[N]=[C]([c]2[...
# exp. DeltaG [kcal/mol]                             -0.28 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402747_3400_7_CHEMBL3402751_2100_11, dtype: object
# 0                                                      CHEMBL3402747_3400_7
# 1                                                    CHEMBL3402752_30000_12
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([c]2[c]([H])[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                               1.3 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402747_3400_7_CHEMBL3402752_30000_12, dtype: object
# 0                                                      CHEMBL3402747_3400_7
# 1                                                     CHEMBL3402755_4200_15
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                              0.13 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402747_3400_7_CHEMBL3402755_4200_15, dtype: object
# 0                                                      CHEMBL3402748_5300_8
# 1                                                     CHEMBL3402751_2100_11
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([C]([H])([H])[H])[N]([H])[C]([...
# Smiles2                       [H][C]1=[C]([C]([H])([H])[H])[N]=[C]([c]2[...
# exp. DeltaG [kcal/mol]                             -0.55 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402748_5300_8_CHEMBL3402751_2100_11, dtype: object
# 0                                                       CHEMBL3402749_500_9
# 1                                                      CHEMBL3402748_5300_8
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([C]([H])([H])[H])[O][C]([c]2[c...
# Smiles2                       [H][C]1=[C]([C]([H])([H])[H])[N]([H])[C]([...
# exp. DeltaG [kcal/mol]                              1.41 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402749_500_9_CHEMBL3402748_5300_8, dtype: object
# 0                                                      CHEMBL3402750_400_10
# 1                                                      CHEMBL3402748_5300_8
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([C]([H])([H])[H])[S][C]([c]2[c...
# Smiles2                       [H][C]1=[C]([C]([H])([H])[H])[N]([H])[C]([...
# exp. DeltaG [kcal/mol]                              1.54 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402750_400_10_CHEMBL3402748_5300_8, dtype: object
# 0                                                      CHEMBL3402750_400_10
# 1                                                       CHEMBL3402749_500_9
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([C]([H])([H])[H])[S][C]([c]2[c...
# Smiles2                       [H][C]1=[C]([C]([H])([H])[H])[O][C]([c]2[c...
# exp. DeltaG [kcal/mol]                              0.13 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402750_400_10_CHEMBL3402749_500_9, dtype: object
# 0                                                      CHEMBL3402750_400_10
# 1                                                     CHEMBL3402751_2100_11
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([C]([H])([H])[H])[S][C]([c]2[c...
# Smiles2                       [H][C]1=[C]([C]([H])([H])[H])[N]=[C]([c]2[...
# exp. DeltaG [kcal/mol]                              0.99 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402750_400_10_CHEMBL3402751_2100_11, dtype: object
# 0                                                    CHEMBL3402752_30000_12
# 1                                                     CHEMBL3402751_2100_11
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([c]2[c]([H])[c]([H])[c]([H])[c...
# Smiles2                       [H][C]1=[C]([C]([H])([H])[H])[N]=[C]([c]2[...
# exp. DeltaG [kcal/mol]                             -1.58 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402752_30000_12_CHEMBL3402751_2100_11, dtype: object
# 0                                                    CHEMBL3402752_30000_12
# 1                                                       CHEMBL3402754_40_14
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([c]2[c]([H])[c]([H])[c]([H])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                             -3.95 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402752_30000_12_CHEMBL3402754_40_14, dtype: object
# 0                                                      CHEMBL3402753_200_13
# 1                                                      CHEMBL3402747_3400_7
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                              1.69 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402753_200_13_CHEMBL3402747_3400_7, dtype: object
# 0                                                      CHEMBL3402753_200_13
# 1                                                      CHEMBL3402750_400_10
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([C]([H])([H])[H])[S][C]([c]2[c...
# exp. DeltaG [kcal/mol]                              0.42 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402753_200_13_CHEMBL3402750_400_10, dtype: object
# 0                                                      CHEMBL3402753_200_13
# 1                                                     CHEMBL3402755_4200_15
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                              1.82 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402753_200_13_CHEMBL3402755_4200_15, dtype: object
# 0                                                      CHEMBL3402753_200_13
# 1                                                        CHEMBL3402761_1_21
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                             -3.15 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402753_200_13_CHEMBL3402761_1_21, dtype: object
# 0                                                     CHEMBL3402755_4200_15
# 1                                                       CHEMBL3402754_40_14
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                             -2.78 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402755_4200_15_CHEMBL3402754_40_14, dtype: object
# 0                                                         CHEMBL3402757_6.5
# 1                                                         CHEMBL3402756_2.7
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                             -0.52 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402757_6.5_CHEMBL3402756_2.7, dtype: object
# 0                                                          CHEMBL3402758_10
# 1                                                          CHEMBL3402742_23
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[n][c]([H]...
# Smiles2                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# exp. DeltaG [kcal/mol]                              0.49 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402758_10_CHEMBL3402742_23, dtype: object
# 0                                                          CHEMBL3402758_10
# 1                                                         CHEMBL3402756_2.7
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[n][c]([H]...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                             -0.78 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402758_10_CHEMBL3402756_2.7, dtype: object
# 0                                                          CHEMBL3402758_10
# 1                                                           CHEMBL3402760_1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[n][c]([H]...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                             -1.37 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402758_10_CHEMBL3402760_1, dtype: object
# 0                                                         CHEMBL3402759_5.7
# 1                                                         CHEMBL3402757_6.5
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                              0.08 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402759_5.7_CHEMBL3402757_6.5, dtype: object
# 0                                                         CHEMBL3402759_5.7
# 1                                                          CHEMBL3402758_10
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[n][c]([H]...
# exp. DeltaG [kcal/mol]                              0.34 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402759_5.7_CHEMBL3402758_10, dtype: object
# 0                                                         CHEMBL3402759_5.7
# 1                                                          CHEMBL3402763_90
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# Smiles2                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# exp. DeltaG [kcal/mol]                              1.65 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402759_5.7_CHEMBL3402763_90, dtype: object
# 0                                                        CHEMBL3402761_1_21
# 1                                                       CHEMBL3402754_40_14
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                              2.19 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402761_1_21_CHEMBL3402754_40_14, dtype: object
# 0                                                        CHEMBL3402761_1_21
# 1                                                     CHEMBL3402755_4200_15
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                              4.97 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402761_1_21_CHEMBL3402755_4200_15, dtype: object
# 0                                                        CHEMBL3402761_1_21
# 1                                                           CHEMBL3402760_1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                               0.0 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402761_1_21_CHEMBL3402760_1, dtype: object
# 0                                                        CHEMBL3402761_1_21
# 1                                                           CHEMBL3402762_1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                               0.0 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402761_1_21_CHEMBL3402762_1, dtype: object
# 0                                                           CHEMBL3402762_1
# 1                                                           CHEMBL3402760_1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                               0.0 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402762_1_CHEMBL3402760_1, dtype: object
# 0                                                          CHEMBL3402763_90
# 1                                                          CHEMBL3402764_90
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                               0.0 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402763_90_CHEMBL3402764_90, dtype: object
# 0                                          CHEMBL3402765_11-charged-pKa-8.1
# 1                                                          CHEMBL3402742_23
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][c]1[c]([H])[c]([N]([H])[C](=[O])[O][C]...
# exp. DeltaG [kcal/mol]                              0.43 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402742_23, dtype: object
# 0                                          CHEMBL3402765_11-charged-pKa-8.1
# 1                                                          CHEMBL3402743_42
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                              0.79 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402743_42, dtype: object
# 0                                          CHEMBL3402765_11-charged-pKa-8.1
# 1                                                       CHEMBL3402744_300_4
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                              1.97 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402744_300_4, dtype: object
# 0                                          CHEMBL3402765_11-charged-pKa-8.1
# 1                                                       CHEMBL3402745_200_5
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# exp. DeltaG [kcal/mol]                              1.72 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402745_200_5, dtype: object
# 0                                          CHEMBL3402765_11-charged-pKa-8.1
# 1                                                           CHEMBL3402760_1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                             -1.43 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402760_1, dtype: object
# 0                                          CHEMBL3402765_11-charged-pKa-8.1
# 1                                                          CHEMBL3402764_90
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([F])[c...
# Smiles2                       [H][C]1=[C]([H])[C]([c]2[c]([H])[c]([H])[c...
# exp. DeltaG [kcal/mol]                              1.25 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402764_90, dtype: object
#           val       err  aerr  conv      env  repeat target  \
# 0   -2.595602  0.050191   NaN   NaN    water       1   cmet
# 1   -3.044933  0.074092   NaN   NaN  complex       1   cmet
# 2   -2.581262  0.052581   NaN   NaN    water       2   cmet
# 3   -3.317400  0.059751   NaN   NaN  complex       2   cmet
# 4   -2.643403  0.064532   NaN   NaN    water       3   cmet
# 5   -3.133365  0.054971   NaN   NaN  complex       3   cmet
# 6    2.808317  0.069312   NaN   NaN    water       1   cmet
# 7    2.454589  0.090822   NaN   NaN  complex       1   cmet
# 8    2.805927  0.059751   NaN   NaN    water       2   cmet
# 9    3.169216  0.074092   NaN   NaN  complex       2   cmet
# 10   2.774857  0.062141   NaN   NaN    water       3   cmet
# 11   2.241874  0.054971   NaN   NaN  complex       3   cmet
# 12   7.260994  0.066922   NaN   NaN    water       1   cmet
# 13   7.758126  0.078872   NaN   NaN  complex       1   cmet
# 14   7.234704  0.059751   NaN   NaN    water       2   cmet
# 15   8.116635  0.114723   NaN   NaN  complex       2   cmet
# 16   7.100860  0.064532   NaN   NaN    water       3   cmet
# 17   7.566922  0.081262   NaN   NaN  complex       3   cmet
# 18 -29.890057  0.057361   NaN   NaN    water       1   cmet
# 19 -26.818834  0.188815   NaN   NaN  complex       1   cmet
# 20 -30.105163  0.057361   NaN   NaN    water       2   cmet
# 21 -28.819312  0.265296   NaN   NaN  complex       2   cmet
# 22 -29.894837  0.052581   NaN   NaN    water       3   cmet
# 23 -27.380497  0.152964   NaN   NaN  complex       3   cmet
# 24 -50.296367  0.069312   NaN   NaN    water       1   cmet
# 25 -50.489962  0.341778   NaN   NaN  complex       1   cmet
# 26 -50.353728  0.074092   NaN   NaN    water       2   cmet
# 27 -46.517686  0.181644   NaN   NaN  complex       2   cmet
# 28 -50.348948  0.062141   NaN   NaN    water       3   cmet
# 29 -49.689293  0.272467   NaN   NaN  complex       3   cmet
# 30 -20.380019  0.026291   NaN   NaN    water       1   cmet
# 31 -20.356119  0.050191   NaN   NaN  complex       1   cmet
# 32 -20.389579  0.028681   NaN   NaN    water       2   cmet
# 33 -20.382409  0.035851   NaN   NaN  complex       2   cmet
# 34 -20.425430  0.028681   NaN   NaN    water       3   cmet
# 35 -20.248566  0.047801   NaN   NaN  complex       3   cmet
# 36  11.472275  0.109943   NaN   NaN    water       1   cmet
# 37   8.891013  0.195985   NaN   NaN  complex       1   cmet
# 38  11.257170  0.107553   NaN   NaN    water       2   cmet
# 39   9.091778  0.160134   NaN   NaN  complex       2   cmet
# 40  11.589388  0.107553   NaN   NaN    water       3   cmet
# 41   9.345124  0.162524   NaN   NaN  complex       3   cmet
# 42 -39.966539  0.050191   NaN   NaN    water       1   cmet
# 43 -43.886233  0.088432   NaN   NaN  complex       1   cmet
# 44 -39.973709  0.052581   NaN   NaN    water       2   cmet
# 45 -42.896750  0.093212   NaN   NaN  complex       2   cmet
# 46 -39.964149  0.045411   NaN   NaN    water       3   cmet
# 47 -42.743786  0.112333   NaN   NaN  complex       3   cmet
#
#                                                edge failed
# 0      edge_CHEMBL3402744_300_4_CHEMBL3402745_200_5  False
# 1      edge_CHEMBL3402744_300_4_CHEMBL3402745_200_5  False
# 2      edge_CHEMBL3402744_300_4_CHEMBL3402745_200_5  False
# 3      edge_CHEMBL3402744_300_4_CHEMBL3402745_200_5  False
# 4      edge_CHEMBL3402744_300_4_CHEMBL3402745_200_5  False
# 5      edge_CHEMBL3402744_300_4_CHEMBL3402745_200_5  False
# 6   edge_CHEMBL3402747_3400_7_CHEMBL3402751_2100_11  False
# 7   edge_CHEMBL3402747_3400_7_CHEMBL3402751_2100_11  False
# 8   edge_CHEMBL3402747_3400_7_CHEMBL3402751_2100_11  False
# 9   edge_CHEMBL3402747_3400_7_CHEMBL3402751_2100_11  False
# 10  edge_CHEMBL3402747_3400_7_CHEMBL3402751_2100_11  False
# 11  edge_CHEMBL3402747_3400_7_CHEMBL3402751_2100_11  False
# 12  edge_CHEMBL3402748_5300_8_CHEMBL3402751_2100_11  False
# 13  edge_CHEMBL3402748_5300_8_CHEMBL3402751_2100_11  False
# 14  edge_CHEMBL3402748_5300_8_CHEMBL3402751_2100_11  False
# 15  edge_CHEMBL3402748_5300_8_CHEMBL3402751_2100_11  False
# 16  edge_CHEMBL3402748_5300_8_CHEMBL3402751_2100_11  False
# 17  edge_CHEMBL3402748_5300_8_CHEMBL3402751_2100_11  False
# 18    edge_CHEMBL3402749_500_9_CHEMBL3402748_5300_8  False
# 19    edge_CHEMBL3402749_500_9_CHEMBL3402748_5300_8  False
# 20    edge_CHEMBL3402749_500_9_CHEMBL3402748_5300_8  False
# 21    edge_CHEMBL3402749_500_9_CHEMBL3402748_5300_8  False
# 22    edge_CHEMBL3402749_500_9_CHEMBL3402748_5300_8  False
# 23    edge_CHEMBL3402749_500_9_CHEMBL3402748_5300_8  False
# 24   edge_CHEMBL3402750_400_10_CHEMBL3402748_5300_8  False
# 25   edge_CHEMBL3402750_400_10_CHEMBL3402748_5300_8  False
# 26   edge_CHEMBL3402750_400_10_CHEMBL3402748_5300_8  False
# 27   edge_CHEMBL3402750_400_10_CHEMBL3402748_5300_8  False
# 28   edge_CHEMBL3402750_400_10_CHEMBL3402748_5300_8  False
# 29   edge_CHEMBL3402750_400_10_CHEMBL3402748_5300_8  False
# 30    edge_CHEMBL3402750_400_10_CHEMBL3402749_500_9  False
# 31    edge_CHEMBL3402750_400_10_CHEMBL3402749_500_9  False
# 32    edge_CHEMBL3402750_400_10_CHEMBL3402749_500_9  False
# 33    edge_CHEMBL3402750_400_10_CHEMBL3402749_500_9  False
# 34    edge_CHEMBL3402750_400_10_CHEMBL3402749_500_9  False
# 35    edge_CHEMBL3402750_400_10_CHEMBL3402749_500_9  False
# 36  edge_CHEMBL3402752_30000_12_CHEMBL3402754_40_14  False
# 37  edge_CHEMBL3402752_30000_12_CHEMBL3402754_40_14  False
# 38  edge_CHEMBL3402752_30000_12_CHEMBL3402754_40_14  False
# 39  edge_CHEMBL3402752_30000_12_CHEMBL3402754_40_14  False
# 40  edge_CHEMBL3402752_30000_12_CHEMBL3402754_40_14  False
# 41  edge_CHEMBL3402752_30000_12_CHEMBL3402754_40_14  False
# 42   edge_CHEMBL3402755_4200_15_CHEMBL3402754_40_14  False
# 43   edge_CHEMBL3402755_4200_15_CHEMBL3402754_40_14  False
# 44   edge_CHEMBL3402755_4200_15_CHEMBL3402754_40_14  False
# 45   edge_CHEMBL3402755_4200_15_CHEMBL3402754_40_14  False
# 46   edge_CHEMBL3402755_4200_15_CHEMBL3402754_40_14  False
# 47   edge_CHEMBL3402755_4200_15_CHEMBL3402754_40_14  False

# %%
for ff in ['gaff', 'cgenff']:
    dfs = []
    for target in targets.target_dict:
        df = getGapsysSingleRepeatsResults(target, ff)
        if df is not None and df.shape[0]>0:
            dfs.append(df)
    df = pd.concat(dfs, axis=0)
    df.to_csv(f'00b_finished_simulations_{ff}.csv')
# Out:
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/jnk1_gaff_protein.dat
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/jnk1_gaff_water.dat
# /home/dhahn3/miniconda3/envs/off/lib/python3.7/site-packages/pandas/core/dtypes/cast.py:1638: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
# 0                                                                   17124-1
# 1                                                                   18634-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(c(cc2OC)Br)OC)N...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(ccc2OC)OC)N)C#N...
# exp. DeltaG [kcal/mol]                             -0.33 kilocalorie / mole
# exp. Error [kcal/mol]                               0.29 kilocalorie / mole
# Name: 17124_18634, dtype: object
# 0                                                                   18626-1
# 1                                                                   18624-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cccc(c2)Cl)N)C#N
# d...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2)N)C#N
# dtype...
# exp. DeltaG [kcal/mol]                              0.38 kilocalorie / mole
# exp. Error [kcal/mol]                               0.21 kilocalorie / mole
# Name: 18626_18624, dtype: object
# 0                                                                   18636-1
# 1                                                                   18625-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(ccc2Br)Br)N)C#N...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2Cl)N)C#N
# dty...
# exp. DeltaG [kcal/mol]                              -0.6 kilocalorie / mole
# exp. Error [kcal/mol]                               0.36 kilocalorie / mole
# Name: 18636_18625, dtype: object
# 0                                                                   18632-1
# 1                                                                   18624-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cccc(c2)OC)N)C#N
# d...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2)N)C#N
# dtype...
# exp. DeltaG [kcal/mol]                               0.6 kilocalorie / mole
# exp. Error [kcal/mol]                               0.31 kilocalorie / mole
# Name: 18632_18624, dtype: object
# 0                                                                   18635-1
# 1                                                                   18625-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(ccc2C)C)N)C#N
# d...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2Cl)N)C#N
# dty...
# exp. DeltaG [kcal/mol]                             -0.83 kilocalorie / mole
# exp. Error [kcal/mol]                               0.18 kilocalorie / mole
# Name: 18635_18625, dtype: object
# 0                                                                   18626-1
# 1                                                                   18658-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cccc(c2)Cl)N)C#N
# d...
# Smiles2                       COc1ccc(c(c1)CC(=O)Nc2cc(c(c(n2)OCCO)C#N)N...
# exp. DeltaG [kcal/mol]                             -0.84 kilocalorie / mole
# exp. Error [kcal/mol]                               0.17 kilocalorie / mole
# Name: 18626_18658, dtype: object
# 0                                                                   18639-1
# 1                                                                   18658-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(c(cc2OC)[N+](=O...
# Smiles2                       COc1ccc(c(c1)CC(=O)Nc2cc(c(c(n2)OCCO)C#N)N...
# exp. DeltaG [kcal/mol]                              0.04 kilocalorie / mole
# exp. Error [kcal/mol]                               0.15 kilocalorie / mole
# Name: 18639_18658, dtype: object
# 0                                                                   18626-1
# 1                                                                   18625-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cccc(c2)Cl)N)C#N
# d...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2Cl)N)C#N
# dty...
# exp. DeltaG [kcal/mol]                              0.77 kilocalorie / mole
# exp. Error [kcal/mol]                               0.21 kilocalorie / mole
# Name: 18626_18625, dtype: object
# 0                                                                   18638-1
# 1                                                                   18658-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(c(cc2OC)S(=O)(=...
# Smiles2                       COc1ccc(c(c1)CC(=O)Nc2cc(c(c(n2)OCCO)C#N)N...
# exp. DeltaG [kcal/mol]                               0.4 kilocalorie / mole
# exp. Error [kcal/mol]                               0.12 kilocalorie / mole
# Name: 18638_18658, dtype: object
# 0                                                                   18628-1
# 1                                                                   18624-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2C)N)C#N
# dtyp...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2)N)C#N
# dtype...
# exp. DeltaG [kcal/mol]                              0.21 kilocalorie / mole
# exp. Error [kcal/mol]                               0.23 kilocalorie / mole
# Name: 18628_18624, dtype: object
# 0                                                                   18631-1
# 1                                                                   18660-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2OC)N)C#N
# dty...
# Smiles2                       COc1ccc(c(c1)CC(=O)Nc2cc(c(c(n2)OCCS(=O)(=...
# exp. DeltaG [kcal/mol]                              0.72 kilocalorie / mole
# exp. Error [kcal/mol]                               0.24 kilocalorie / mole
# Name: 18631_18660, dtype: object
# 0                                                                   18638-1
# 1                                                                   18634-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(c(cc2OC)S(=O)(=...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(ccc2OC)OC)N)C#N...
# exp. DeltaG [kcal/mol]                               0.1 kilocalorie / mole
# exp. Error [kcal/mol]                               0.09 kilocalorie / mole
# Name: 18638_18634, dtype: object
# 0                                                                   18626-1
# 1                                                                   18632-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cccc(c2)Cl)N)C#N
# d...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2cccc(c2)OC)N)C#N
# d...
# exp. DeltaG [kcal/mol]                             -0.22 kilocalorie / mole
# exp. Error [kcal/mol]                                0.3 kilocalorie / mole
# Name: 18626_18632, dtype: object
# 0                                                                   18626-1
# 1                                                                   18630-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cccc(c2)Cl)N)C#N
# d...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccc(cc2)C)N)C#N
# dt...
# exp. DeltaG [kcal/mol]                             -0.28 kilocalorie / mole
# exp. Error [kcal/mol]                               0.14 kilocalorie / mole
# Name: 18626_18630, dtype: object
# 0                                                                   18631-1
# 1                                                                   18624-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2OC)N)C#N
# dty...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2)N)C#N
# dtype...
# exp. DeltaG [kcal/mol]                              0.93 kilocalorie / mole
# exp. Error [kcal/mol]                               0.27 kilocalorie / mole
# Name: 18631_18624, dtype: object
# 0                                                                   18629-1
# 1                                                                   18627-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cccc(c2)C)N)C#N
# dt...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccc(cc2)Cl)N)C#N
# d...
# exp. DeltaG [kcal/mol]                              0.19 kilocalorie / mole
# exp. Error [kcal/mol]                               0.19 kilocalorie / mole
# Name: 18629_18627, dtype: object
# 0                                                                   18634-1
# 1                                                                   18637-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(ccc2OC)OC)N)C#N...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(c(cc2OC)NC(=O)C...
# exp. DeltaG [kcal/mol]                             -0.14 kilocalorie / mole
# exp. Error [kcal/mol]                               0.27 kilocalorie / mole
# Name: 18634_18637, dtype: object
# 0                                                                   18626-1
# 1                                                                   18627-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cccc(c2)Cl)N)C#N
# d...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccc(cc2)Cl)N)C#N
# d...
# exp. DeltaG [kcal/mol]                              0.39 kilocalorie / mole
# exp. Error [kcal/mol]                               0.22 kilocalorie / mole
# Name: 18626_18627, dtype: object
# 0                                                                   18631-1
# 1                                                                   18652-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2OC)N)C#N
# dty...
# Smiles2                       CC(C)Oc1c(c(cc(n1)NC(=O)Cc2cc(c(cc2OC)S(=O...
# exp. DeltaG [kcal/mol]                             -1.28 kilocalorie / mole
# exp. Error [kcal/mol]                               0.25 kilocalorie / mole
# Name: 18631_18652, dtype: object
# 0                                                                   18637-1
# 1                                                                   18631-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(c(cc2OC)NC(=O)C...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2OC)N)C#N
# dty...
# exp. DeltaG [kcal/mol]                              0.73 kilocalorie / mole
# exp. Error [kcal/mol]                               0.35 kilocalorie / mole
# Name: 18637_18631, dtype: object
# 0                                                                   18626-1
# 1                                                                   18634-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cccc(c2)Cl)N)C#N
# d...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(ccc2OC)OC)N)C#N...
# exp. DeltaG [kcal/mol]                             -1.14 kilocalorie / mole
# exp. Error [kcal/mol]                               0.15 kilocalorie / mole
# Name: 18626_18634, dtype: object
# 0                                                                   18633-1
# 1                                                                   18624-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2ccc(cc2)OC)N)C#N
# d...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2)N)C#N
# dtype...
# exp. DeltaG [kcal/mol]                              0.69 kilocalorie / mole
# exp. Error [kcal/mol]                               0.25 kilocalorie / mole
# Name: 18633_18624, dtype: object
# 0                                                                   17124-1
# 1                                                                   18631-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(c(cc2OC)Br)OC)N...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2OC)N)C#N
# dty...
# exp. DeltaG [kcal/mol]                              0.26 kilocalorie / mole
# exp. Error [kcal/mol]                               0.37 kilocalorie / mole
# Name: 17124_18631, dtype: object
# 0                                                                   18627-1
# 1                                                                   18630-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2ccc(cc2)Cl)N)C#N
# d...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccc(cc2)C)N)C#N
# dt...
# exp. DeltaG [kcal/mol]                             -0.67 kilocalorie / mole
# exp. Error [kcal/mol]                               0.17 kilocalorie / mole
# Name: 18627_18630, dtype: object
# 0                                                                   18659-1
# 1                                                                   18634-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       COCCOc1c(c(cc(n1)NC(=O)Cc2cc(ccc2OC)OC)N)C...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(ccc2OC)OC)N)C#N...
# exp. DeltaG [kcal/mol]                             -0.54 kilocalorie / mole
# exp. Error [kcal/mol]                               0.08 kilocalorie / mole
# Name: 18659_18634, dtype: object
# 0                                                                   18636-1
# 1                                                                   18624-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(ccc2Br)Br)N)C#N...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2)N)C#N
# dtype...
# exp. DeltaG [kcal/mol]                             -0.99 kilocalorie / mole
# exp. Error [kcal/mol]                               0.35 kilocalorie / mole
# Name: 18636_18624, dtype: object
# 0                                                                   18626-1
# 1                                                                   18628-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cccc(c2)Cl)N)C#N
# d...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2C)N)C#N
# dtyp...
# exp. DeltaG [kcal/mol]                              0.17 kilocalorie / mole
# exp. Error [kcal/mol]                               0.23 kilocalorie / mole
# Name: 18626_18628, dtype: object
# 0                                                                   18626-1
# 1                                                                   18660-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cccc(c2)Cl)N)C#N
# d...
# Smiles2                       COc1ccc(c(c1)CC(=O)Nc2cc(c(c(n2)OCCS(=O)(=...
# exp. DeltaG [kcal/mol]                              0.17 kilocalorie / mole
# exp. Error [kcal/mol]                               0.16 kilocalorie / mole
# Name: 18626_18660, dtype: object
# 0                                                                   18626-1
# 1                                                                   18659-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cccc(c2)Cl)N)C#N
# d...
# Smiles2                       COCCOc1c(c(cc(n1)NC(=O)Cc2cc(ccc2OC)OC)N)C...
# exp. DeltaG [kcal/mol]                              -0.6 kilocalorie / mole
# exp. Error [kcal/mol]                               0.16 kilocalorie / mole
# Name: 18626_18659, dtype: object
# 0                                                                   18639-1
# 1                                                                   18634-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(c(cc2OC)[N+](=O...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(ccc2OC)OC)N)C#N...
# exp. DeltaG [kcal/mol]                             -0.26 kilocalorie / mole
# exp. Error [kcal/mol]                               0.13 kilocalorie / mole
# Name: 18639_18634, dtype: object
# 0                                                                   18635-1
# 1                                                                   18624-1
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1c(c(cc(n1)NC(=O)Cc2cc(ccc2C)C)N)C#N
# d...
# Smiles2                       CCOc1c(c(cc(n1)NC(=O)Cc2ccccc2)N)C#N
# dtype...
# exp. DeltaG [kcal/mol]                             -1.22 kilocalorie / mole
# exp. Error [kcal/mol]                               0.17 kilocalorie / mole
# Name: 18635_18624, dtype: object
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/pde2_gaff_protein.dat
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/pde2_gaff_water.dat
# 0                                                                  49220392
# 1                                                                  49137530
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1ccc(c(c1)c2nnc3n2c4cc(ccc4nc3C)CN5CCO...
# Smiles2                       CCCCOc1cc(cnc1)c2nnc3n2c4cc(ccc4nc3C)CN5CC...
# exp. DeltaG [kcal/mol]                               0.1 kilocalorie / mole
# exp. Error [kcal/mol]                                0.5 kilocalorie / mole
# Name: 49220392_49137530, dtype: object
# 0                                                                  49932714
# 1                                                                  49137530
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# Smiles2                       CCCCOc1cc(cnc1)c2nnc3n2c4cc(ccc4nc3C)CN5CC...
# exp. DeltaG [kcal/mol]                              -1.3 kilocalorie / mole
# exp. Error [kcal/mol]                               0.41 kilocalorie / mole
# Name: 49932714_49137530, dtype: object
# 0                                                                  49582468
# 1                                                                  49137530
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOCc1cc(cnc1)c2nnc3n2c4cc(ccc4nc3C)CN5CCO...
# Smiles2                       CCCCOc1cc(cnc1)c2nnc3n2c4cc(ccc4nc3C)CN5CC...
# exp. DeltaG [kcal/mol]                             -0.83 kilocalorie / mole
# exp. Error [kcal/mol]                               0.46 kilocalorie / mole
# Name: 49582468_49137530, dtype: object
# 0                                                                  49396360
# 1                                                                  49137530
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCCOc1cc(cnc1)c2nnc3n2c4cc(ccc4nc3C)CN5CCO...
# Smiles2                       CCCCOc1cc(cnc1)c2nnc3n2c4cc(ccc4nc3C)CN5CC...
# exp. DeltaG [kcal/mol]                             -0.85 kilocalorie / mole
# exp. Error [kcal/mol]                               0.47 kilocalorie / mole
# Name: 49396360_49137530, dtype: object
# 0                                                                  50181001
# 1                                                                  49137530
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCCCOc1cc(cnc1Cl)c2nnc3n2c4cc(ccc4nc3C)CN5...
# Smiles2                       CCCCOc1cc(cnc1)c2nnc3n2c4cc(ccc4nc3C)CN5CC...
# exp. DeltaG [kcal/mol]                             -1.66 kilocalorie / mole
# exp. Error [kcal/mol]                               0.42 kilocalorie / mole
# Name: 50181001_49137530, dtype: object
# 0                                                                  49585367
# 1                                                                  49137530
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# Smiles2                       CCCCOc1cc(cnc1)c2nnc3n2c4cc(ccc4nc3C)CN5CC...
# exp. DeltaG [kcal/mol]                             -1.56 kilocalorie / mole
# exp. Error [kcal/mol]                               0.49 kilocalorie / mole
# Name: 49585367_49137530, dtype: object
# 0                                                                  49220392
# 1                                                                  49175828
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOc1ccc(c(c1)c2nnc3n2c4cc(ccc4nc3C)CN5CCO...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(ccc5...
# exp. DeltaG [kcal/mol]                             -0.74 kilocalorie / mole
# exp. Error [kcal/mol]                               0.57 kilocalorie / mole
# Name: 49220392_49175828, dtype: object
# 0                                                                  49220548
# 1                                                                  49220392
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCCOc1ccc(c(c1)c2nnc3n2c4cc(ccc4nc3C)CN5CC...
# Smiles2                       CCOc1ccc(c(c1)c2nnc3n2c4cc(ccc4nc3C)CN5CCO...
# exp. DeltaG [kcal/mol]                             -0.03 kilocalorie / mole
# exp. Error [kcal/mol]                               0.37 kilocalorie / mole
# Name: 49220548_49220392, dtype: object
# 0                                                                  49220548
# 1                                                                  49932129
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCCOc1ccc(c(c1)c2nnc3n2c4cc(ccc4nc3C)CN5CC...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                              1.56 kilocalorie / mole
# exp. Error [kcal/mol]                               0.41 kilocalorie / mole
# Name: 49220548_49932129, dtype: object
# 0                                                                  49582468
# 1                                                                  49932129
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCOCc1cc(cnc1)c2nnc3n2c4cc(ccc4nc3C)CN5CCO...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                              0.66 kilocalorie / mole
# exp. Error [kcal/mol]                                0.4 kilocalorie / mole
# Name: 49582468_49932129, dtype: object
# 0                                                                  49396360
# 1                                                                  49175828
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCCOc1cc(cnc1)c2nnc3n2c4cc(ccc4nc3C)CN5CCO...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(ccc5...
# exp. DeltaG [kcal/mol]                             -1.69 kilocalorie / mole
# exp. Error [kcal/mol]                               0.54 kilocalorie / mole
# Name: 49396360_49175828, dtype: object
# 0                                                                  49175828
# 1                                                                  49580115
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(ccc5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                              1.89 kilocalorie / mole
# exp. Error [kcal/mol]                               0.56 kilocalorie / mole
# Name: 49175828_49580115, dtype: object
# 0                                                                  49220548
# 1                                                                  49137374
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCCOc1ccc(c(c1)c2nnc3n2c4cc(ccc4nc3C)CN5CC...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(ccc5...
# exp. DeltaG [kcal/mol]                             -0.04 kilocalorie / mole
# exp. Error [kcal/mol]                               0.47 kilocalorie / mole
# Name: 49220548_49137374, dtype: object
# 0                                                                  49220548
# 1                                                                  49580115
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCCOc1ccc(c(c1)c2nnc3n2c4cc(ccc4nc3C)CN5CC...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                              1.12 kilocalorie / mole
# exp. Error [kcal/mol]                               0.35 kilocalorie / mole
# Name: 49220548_49580115, dtype: object
# 0                                                                  49396360
# 1                                                                  49220548
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCCOc1cc(cnc1)c2nnc3n2c4cc(ccc4nc3C)CN5CCO...
# Smiles2                       CCCOc1ccc(c(c1)c2nnc3n2c4cc(ccc4nc3C)CN5CC...
# exp. DeltaG [kcal/mol]                             -0.92 kilocalorie / mole
# exp. Error [kcal/mol]                               0.32 kilocalorie / mole
# Name: 49396360_49220548, dtype: object
# 0                                                                  49932714
# 1                                                                  49582390
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                             -0.91 kilocalorie / mole
# exp. Error [kcal/mol]                               0.41 kilocalorie / mole
# Name: 49932714_49582390, dtype: object
# 0                                                                  49396360
# 1                                                                  49582390
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCCOc1cc(cnc1)c2nnc3n2c4cc(ccc4nc3C)CN5CCO...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                             -0.46 kilocalorie / mole
# exp. Error [kcal/mol]                               0.47 kilocalorie / mole
# Name: 49396360_49582390, dtype: object
# 0                                                                  50181001
# 1                                                                  49582390
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCCCOc1cc(cnc1Cl)c2nnc3n2c4cc(ccc4nc3C)CN5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                             -1.27 kilocalorie / mole
# exp. Error [kcal/mol]                               0.42 kilocalorie / mole
# Name: 50181001_49582390, dtype: object
# 0                                                                  50107616
# 1                                                                  49582390
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                             -1.34 kilocalorie / mole
# exp. Error [kcal/mol]                               0.59 kilocalorie / mole
# Name: 50107616_49582390, dtype: object
# 0                                                                  48168913
# 1                                                                  48271249
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c(cccn1)c2nnc3n2c4cc(ccc4nc3C)CN5CCOCC5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                             -0.45 kilocalorie / mole
# exp. Error [kcal/mol]                               0.34 kilocalorie / mole
# Name: 48168913_48271249, dtype: object
# 0                                                                  49072088
# 1                                                                  48271249
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                             -2.06 kilocalorie / mole
# exp. Error [kcal/mol]                               0.21 kilocalorie / mole
# Name: 49072088_48271249, dtype: object
# 0                                                                  50107616
# 1                                                                  48271249
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                             -1.43 kilocalorie / mole
# exp. Error [kcal/mol]                               0.44 kilocalorie / mole
# Name: 50107616_48271249, dtype: object
# 0                                                                  49137374
# 1                                                                  48271249
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(ccc5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                              0.41 kilocalorie / mole
# exp. Error [kcal/mol]                               0.42 kilocalorie / mole
# Name: 49137374_48271249, dtype: object
# 0                                                                  49932714
# 1                                                                  49175789
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# Smiles2                       CCCCOc1ccc(c(c1)c2nnc3n2c4cc(ccc4nc3C)CN5C...
# exp. DeltaG [kcal/mol]                             -1.25 kilocalorie / mole
# exp. Error [kcal/mol]                                0.3 kilocalorie / mole
# Name: 49932714_49175789, dtype: object
# 0                                                                  49932714
# 1                                                                  49580115
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                             -0.25 kilocalorie / mole
# exp. Error [kcal/mol]                               0.27 kilocalorie / mole
# Name: 49932714_49580115, dtype: object
# 0                                                                  49932714
# 1                                                                  49582468
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# Smiles2                       CCOCc1cc(cnc1)c2nnc3n2c4cc(ccc4nc3C)CN5CCO...
# exp. DeltaG [kcal/mol]                             -0.47 kilocalorie / mole
# exp. Error [kcal/mol]                               0.21 kilocalorie / mole
# Name: 49932714_49582468, dtype: object
# 0                                                                  48168913
# 1                                                                  49585367
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c(cccn1)c2nnc3n2c4cc(ccc4nc3C)CN5CCOCC5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                              0.81 kilocalorie / mole
# exp. Error [kcal/mol]                               0.41 kilocalorie / mole
# Name: 48168913_49585367, dtype: object
# 0                                                                  50107616
# 1                                                                  49585367
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                             -0.17 kilocalorie / mole
# exp. Error [kcal/mol]                                0.5 kilocalorie / mole
# Name: 50107616_49585367, dtype: object
# 0                                                                  48168913
# 1                                                                  48022468
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c(cccn1)c2nnc3n2c4cc(ccc4nc3C)CN5CCOCC5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5c(cccc5...
# exp. DeltaG [kcal/mol]                             -1.54 kilocalorie / mole
# exp. Error [kcal/mol]                               0.41 kilocalorie / mole
# Name: 48168913_48022468, dtype: object
# 0                                                                  43249674
# 1                                                                  48022468
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5ccccc5C...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5c(cccc5...
# exp. DeltaG [kcal/mol]                              -0.2 kilocalorie / mole
# exp. Error [kcal/mol]                               0.33 kilocalorie / mole
# Name: 43249674_48022468, dtype: object
# 0                                                                  48009208
# 1                                                                  43249674
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5ccc(cc5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5ccccc5C...
# exp. DeltaG [kcal/mol]                             -0.75 kilocalorie / mole
# exp. Error [kcal/mol]                               0.34 kilocalorie / mole
# Name: 48009208_43249674, dtype: object
# 0                                                                  43249674
# 1                                                                  49175789
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5ccccc5C...
# Smiles2                       CCCCOc1ccc(c(c1)c2nnc3n2c4cc(ccc4nc3C)CN5C...
# exp. DeltaG [kcal/mol]                              0.64 kilocalorie / mole
# exp. Error [kcal/mol]                               0.37 kilocalorie / mole
# Name: 43249674_49175789, dtype: object
# 0                                                                  49175789
# 1                                                                  49072088
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       CCCCOc1ccc(c(c1)c2nnc3n2c4cc(ccc4nc3C)CN5C...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(cnc5...
# exp. DeltaG [kcal/mol]                              2.31 kilocalorie / mole
# exp. Error [kcal/mol]                               0.35 kilocalorie / mole
# Name: 49175789_49072088, dtype: object
# 0                                                                  48009208
# 1                                                                  49137374
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5ccc(cc5...
# Smiles2                       Cc1c2nnc(n2c3cc(ccc3n1)CN4CCOCC4)c5cc(ccc5...
# exp. DeltaG [kcal/mol]                             -0.27 kilocalorie / mole
# exp. Error [kcal/mol]                               0.49 kilocalorie / mole
# Name: 48009208_49137374, dtype: object
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/thrombin_gaff_protein.dat
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/thrombin_gaff_water.dat
# 0                                                                        1d
# 1                                                                        6e
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# Smiles2                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# exp. DeltaG [kcal/mol]                             -0.67 kilocalorie / mole
# exp. Error [kcal/mol]                                0.1 kilocalorie / mole
# Name: 1d_6e, dtype: object
# 0                                                                        1d
# 1                                                                         5
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# Smiles2                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# exp. DeltaG [kcal/mol]                              0.67 kilocalorie / mole
# exp. Error [kcal/mol]                               0.07 kilocalorie / mole
# Name: 1d_5, dtype: object
# 0                                                                        1b
# 1                                                                        3b
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# Smiles2                       CCc1cccc(c1)CNC(=O)[C@@H]2CCCN2C(=O)[C@@H]...
# exp. DeltaG [kcal/mol]                               0.6 kilocalorie / mole
# exp. Error [kcal/mol]                               0.23 kilocalorie / mole
# Name: 1b_3b, dtype: object
# 0                                                                        6a
# 1                                                                        1b
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# Smiles2                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# exp. DeltaG [kcal/mol]                              0.72 kilocalorie / mole
# exp. Error [kcal/mol]                                0.2 kilocalorie / mole
# Name: 6a_1b, dtype: object
# 0                                                                        1b
# 1                                                                        1c
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# Smiles2                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# exp. DeltaG [kcal/mol]                              -0.1 kilocalorie / mole
# exp. Error [kcal/mol]                               0.25 kilocalorie / mole
# Name: 1b_1c, dtype: object
# 0                                                                        1d
# 1                                                                        1c
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# Smiles2                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# exp. DeltaG [kcal/mol]                             -0.31 kilocalorie / mole
# exp. Error [kcal/mol]                               0.18 kilocalorie / mole
# Name: 1d_1c, dtype: object
# 0                                                                        1b
# 1                                                                        1a
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# Smiles2                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# exp. DeltaG [kcal/mol]                              0.98 kilocalorie / mole
# exp. Error [kcal/mol]                                0.2 kilocalorie / mole
# Name: 1b_1a, dtype: object
# 0                                                                        1a
# 1                                                                         5
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# Smiles2                       c1ccc(cc1)C[C@H](C(=O)N2CCC[C@H]2C(=O)NCc3...
# exp. DeltaG [kcal/mol]                              -0.1 kilocalorie / mole
# exp. Error [kcal/mol]                               0.05 kilocalorie / mole
# Name: 1a_5, dtype: object
# 0                                                                        3a
# 1                                                                        1d
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       Cc1cccc(c1)CNC(=O)[C@@H]2CCCN2C(=O)[C@@H](...
# ...
# exp. DeltaG [kcal/mol]                              -1.8 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_44_ejm_55, dtype: object
# 0                                                                    ejm_49
# 1                                                                    ejm_31
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])[H])C(=O)N([H])c2c(c(c(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                             -1.81 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_49_ejm_31, dtype: object
# 0                                                                    ejm_31
# 1                                                                    ejm_46
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                             -1.79 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_31_ejm_46, dtype: object
# 0                                                                    jmc_28
# 1                                                                    jmc_27
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                              -0.3 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: jmc_28_jmc_27, dtype: object
# 0                                                                    ejm_42
# 1                                                                    ejm_48
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                              0.79 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_42_ejm_48, dtype: object
# 0                                                                    ejm_31
# 1                                                                    ejm_43
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                              1.29 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_31_ejm_43, dtype: object
# 0                                                                    ejm_50
# 1                                                                    ejm_42
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                             -0.82 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_50_ejm_42, dtype: object
# 0                                                                    ejm_42
# 1                                                                    ejm_55
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                              0.59 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_42_ejm_55, dtype: object
# 0                                                                    jmc_23
# 1                                                                    ejm_46
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                              0.39 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: jmc_23_ejm_46, dtype: object
# 0                                                                    ejm_31
# 1                                                                    ejm_45
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                             -0.02 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_31_ejm_45, dtype: object
# 0                                                                    ejm_55
# 1                                                                    ejm_54
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                             -1.34 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_55_ejm_54, dtype: object
# 0                                                                    ejm_45
# 1                                                                    ejm_42
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                             -0.23 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_45_ejm_42, dtype: object
# 0                                                                    ejm_31
# 1                                                                    jmc_28
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                             -1.45 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_31_jmc_28, dtype: object
# 0                                                                    ejm_31
# 1                                                                    ejm_48
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                              0.54 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_31_ejm_48, dtype: object
# 0                                                                    ejm_47
# 1                                                                    ejm_31
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                              0.16 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_47_ejm_31, dtype: object
# 0                                                                    ejm_47
# 1                                                                    ejm_55
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                               0.5 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_47_ejm_55, dtype: object
# 0                                                                    ejm_44
# 1                                                                    ejm_42
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                             -2.39 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_44_ejm_42, dtype: object
# 0                                                                    jmc_23
# 1                                                                    jmc_27
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                              0.43 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: jmc_23_jmc_27, dtype: object
# 0                                                                    ejm_43
# 1                                                                    ejm_55
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                             -0.95 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_43_ejm_55, dtype: object
# 0                                                                    jmc_23
# 1                                                                    jmc_30
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                              0.77 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: jmc_23_jmc_30, dtype: object
# 0                                                                    jmc_28
# 1                                                                    jmc_30
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                              0.04 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: jmc_28_jmc_30, dtype: object
# 0                                                                    ejm_42
# 1                                                                    ejm_54
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                             -0.75 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_42_ejm_54, dtype: object
# 0                                                                    ejm_49
# 1                                                                    ejm_50
# Mol1                          <img data-content="rdkit/molecule" src="da...
# Mol2                          <img data-content="rdkit/molecule" src="da...
# Smiles1                       [H]c1c(c(c(c(c1[H])[H])C(=O)N([H])c2c(c(c(...
# Smiles2                       [H]c1c(c(c(c(c1[H])Cl)C(=O)N([H])c2c(c(nc(...
# exp. DeltaG [kcal/mol]                             -1.24 kilocalorie / mole
# exp. Error [kcal/mol]                                0.0 kilocalorie / mole
# Name: ejm_49_ejm_50, dtype: object
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/ros1_cgenff_protein.dat
# File /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/ros1_cgenff_protein.dat does not exist.
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/eg5_cgenff_protein.dat
# File /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/eg5_cgenff_protein.dat does not exist.
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/cdk8_cgenff_protein.dat
# File /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/cdk8_cgenff_protein.dat does not exist.
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/hif2a_cgenff_protein.dat
# File /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/hif2a_cgenff_protein.dat does not exist.
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/pfkfb3_cgenff_protein.dat
# File /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/pfkfb3_cgenff_protein.dat does not exist.
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/pde10_cgenff_protein.dat
# File /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/pde10_cgenff_protein.dat does not exist.
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/shp2_cgenff_protein.dat
# File /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/shp2_cgenff_protein.dat does not exist.
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/syk_cgenff_protein.dat
# File /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/syk_cgenff_protein.dat does not exist.
# /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/tnks2_cgenff_protein.dat
# File /tmp/tmpiqftyrw2/protLig_benchmark/dg_data_allRepeats/tnks2_cgenff_protein.dat does not exist.

# %%
author = "gapsys"
for target in targets.target_dict:
    original_df = getGapsysResults(target)
    if original_df is None:
        continue
    os.makedirs(os.path.join(path, targets.get_target_dir(target), results_dir), exist_ok=True)
    for forcefield in ['fep5', 'fep1', 'gaff', 'cgenff']:
        df = original_df.loc[:, np.in1d(original_df.columns.get_level_values(0), ['ligandA', 'ligandB', f'{forcefield}', f'd{forcefield}'])].copy()
        software = list(df.columns.get_level_values(1))[list(df.columns.get_level_values(0)).index(f'{forcefield}')]
        unit = list(df.columns.get_level_values(2))[list(df.columns.get_level_values(0)).index(f'{forcefield}')]
        if unit == 'kj/mol':
            unit = 'kilojoules / mole'
        df.columns = df.columns.get_level_values(0)
        df.rename(columns={0: 'ligandA', 1: 'ligandB', f'{forcefield}': 'DDG', f'd{forcefield}': 'dDDG'}, inplace=True)
        df['unit'] = unit
        if forcefield.startswith('fep'):
            forcefield = f'opls3e_{forcefield[-1]}'
        with open(os.path.join(path, targets.get_target_dir(target), results_dir, f'{target}_{software}_{forcefield}_{author}.yaml'), 'w') as file:
            yaml.dump(df.T.to_dict(), file)
    
    forcefield = 'exp'
    df = original_df.loc[:, np.in1d(original_df.columns.get_level_values(0), ['ligandA', 'ligandB', f'{forcefield}', f'd{forcefield}'])].copy()
    software = list(df.columns.get_level_values(1))[list(df.columns.get_level_values(0)).index(f'{forcefield}')]
    unit = list(df.columns.get_level_values(2))[list(df.columns.get_level_values(0)).index(f'{forcefield}')]
    if unit == 'kj/mol':
        unit = 'kilojoules / mole'
    df.columns = df.columns.get_level_values(0)
    df.rename(columns={0: 'ligandA', 1: 'ligandB', f'{forcefield}': 'DDG', f'd{forcefield}': 'dDDG'}, inplace=True)
    df['unit'] = unit
    with open(os.path.join(path, targets.get_target_dir(target), results_dir, f'{target}_experiment_{author}.yaml'), 'w') as file:
        yaml.dump(df.T.to_dict(), file)

# %% [markdown]
# # Compare experimental values stored in repository with Gapsys exp. data

# %%
for target in targets.target_dict:
    author = "hahn"
    software = "experiment"
    file_name = os.path.join(path, targets.get_target_dir(target), results_dir, 
                                   f'{target}_{software}_{author}.yaml'
                       )
    if os.path.exists(file_name):
        with open(file_name, 'r') as file:
            data1 = yaml.safe_load(file)
    else:
        print(f"File {file_name} for target {target} not available")
        continue
        
    author = "gapsys"
    software = "experiment"
    file_name = os.path.join(path, targets.get_target_dir(target), results_dir, 
                                   f'{target}_{software}_{author}.yaml'
                       )
    if os.path.exists(file_name):
        with open(file_name, 'r') as file:
            data2 = yaml.safe_load(file)
    else:
        print(f"File {file_name} for target {target} not available")
        continue
        
    for e, edata in data1.items():
met_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402742_23
# cmet cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402743_42
# cmet cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402744_300_4
# cmet cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402745_200_5
# cmet cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402760_1
# cmet cmet_edge_CHEMBL3402765_11-charged-pKa-8.1_CHEMBL3402764_90
# bace bace_edge_CAT-24_CAT-17e 1.74 kilocalorie / mole 1.32887189292543 kilocalorie / mole
# bace bace_edge_CAT-24_CAT-17i 2.29 kilocalorie / mole 1.8809751434034416 kilocalorie / mole
# bace_p2 bace_p2_edge_32_L_35_L 0.52 kilocalorie / mole 0.5999043977055448 kilocalorie / mole
# bace_p2 bace_p2_edge_33_L_30_L -0.11 kilocalorie / mole -0.20076481835564053 kilocalorie / mole
# bace_p2 bace_p2_edge_34_L_29_L 0.15 kilocalorie / mole 0.20076481835564053 kilocalorie / mole
# bace_p2 bace_p2_edge_39_L_36_L -0.65 kilocalorie / mole -0.7002868068833652 kilocalorie / mole
# bace_p2 bace_p2_edge_39_L_37_L -0.85 kilocalorie / mole -0.9010516252390057 kilocalorie / mole
# File ./2020-04-09_ros1/10_results/ros1_experiment_gapsys.yaml for target ros1 not available
# File ./2020-06-19_eg5/10_results/eg5_experiment_gapsys.yaml for target eg5 not available
# File ./2020-07-01_cdk8/10_results/cdk8_experiment_gapsys.yaml for target cdk8 not available
# File ./2020-07-03_hif2a/10_results/hif2a_experiment_gapsys.yaml for target hif2a not available
# File ./2020-07-06_pfkfb3/10_results/pfkfb3_experiment_gapsys.yaml for target pfkfb3 not available
# File ./2020-07-10_pde10/10_results/pde10_experiment_gapsys.yaml for target pde10 not available
# File ./2020-07-30_shp2/10_results/shp2_experiment_gapsys.yaml for target shp2 not available
# File ./2020-08-11_syk/10_results/syk_experiment_gapsys.yaml for target syk not available
# File ./2020-08-12_tnks2/10_results/tnks2_experiment_gapsys.yaml for target tnks2 not available

# %% [markdown]
# # Get results from Wang et. al., JACS 2015
# Input file taken from https://pubs.acs.org/doi/suppl/10.1021/ja512751q/suppl_file/ja512751q_si_003.xlsx (retrieval 2020-09-21) and converted to csv file

# %%
def getWangResults(target):    
    file_name = f'{path}/../00_data/input/ja512751q_si_003.csv'
    if not os.path.exists(file_name):
        print(f'File {file_name} does not exist.')        
        return None
    data = pd.read_csv(file_name, sep=',')
    data['system'] = data['system'].apply(lambda x: str(x).lower())
    indeces = data.loc[data['system']!='nan', :].index
    data_per_target = [data.loc[indeces[i]:indeces[i+1]-1,:] for i in range(indeces.shape[0]-1)]
    data_per_target = {d['system'].iloc[0]: d for d in data_per_target}
    for t, d in data_per_target.items():
        d.index = [f'{target}_edge_{x["Ligand1"]}_{x["Ligand2"]}' for i, x in d.iterrows()]
        d = d[['Ligand1', 'Ligand2', 'bennett_ddG', 'bennett_error']]
        d = d.rename(columns={'Ligand1': 'LigandA',
                             'Ligand2': 'LigandB',
                             'bennett_ddG': 'DDG',
                             'bennett_error': 'dDDG'})
        d['unit'] = 'kilocalories / mole'
        data_per_target[t] = d
    if target in data_per_target:
        return data_per_target[target]
    else:
        return None
getWangResults('jnk1').head()
# Out:
#                            LigandA  LigandB   DDG  dDDG                 unit
# jnk1_edge_17124-1_18634-1  17124-1  18634-1  0.47  0.08  kilocalories / mole
# jnk1_edge_18626-1_18624-1  18626-1  18624-1  0.76  0.08  kilocalories / mole
# jnk1_edge_18636-1_18625-1  18636-1  18625-1 -0.30  0.09  kilocalories / mole
# jnk1_edge_18632-1_18624-1  18632-1  18624-1  0.60  0.09  kilocalories / mole
# jnk1_edge_18635-1_18625-1  18635-1  18625-1  0.97  0.07  kilocalories / mole

# %%
author = 'wang'
software = 'fep+'
forcefield = 'opls2.1'

# %%
for target in targets.target_dict:
    df = getWangResults(target)
    if df is None:
        continue
    os.makedirs(os.path.join(path, targets.get_target_dir(target), results_dir), exist_ok=True)
    with open(os.path.join(path, targets.get_target_dir(target), results_dir, f'{target}_{software}_{forcefield}_{author}.yaml'), 'w') as file:
        yaml.dump(df.T.to_dict(), file)

# %% [markdown]
# # Gather fep-benchmark data (Schindler, Merck KGaA)

# %%
# Create temporary dir
temp_directory = tempfile.mkdtemp()
repo = git.Repo.clone_from('https://github.com/MCompChem/fep-benchmark', temp_directory, branch='v1.0')

# %%
# dict to match names
# <name in Schindler et al.> : <name in protein ligand benchmark>
cmet_dict = {'CHEMBL3402753_200': 'CHEMBL3402753_200_13',
 'CHEMBL3402759_5.7': 'CHEMBL3402759_5.7',
 'CHEMBL3402747_3400': 'CHEMBL3402747_3400_7',
 'CHEMBL3402744_300': 'CHEMBL3402744_300_4',
 'CHEMBL3402745_200': 'CHEMBL3402745_200_5',
 'CHEMBL3402761_1': 'CHEMBL3402761_1_21',
 'CHEMBL3402750_400': 'CHEMBL3402750_400_10',
 'CHEMBL3402743_42': 'CHEMBL3402743_42',
 'CHEMBL3402752_30000': 'CHEMBL3402752_30000_12',
 'CHEMBL3402755_4200': 'CHEMBL3402755_4200_15',
 'CHEMBL3402758_10': 'CHEMBL3402758_10',
 'CHEMBL3402749_500': 'CHEMBL3402749_500_9',
 'CHEMBL3402757_6.5': 'CHEMBL3402757_6.5',
 'CHEMBL3402765_11-charged-pKa-8.1': 'CHEMBL3402765_11-charged-pKa-8.1',
 'CHEMBL3402762_1': 'CHEMBL3402762_1',
 'CHEMBL3402742_23': 'CHEMBL3402742_23',
 'CHEMBL3402754_40': 'CHEMBL3402754_40_14',
 'CHEMBL3402748_5300': 'CHEMBL3402748_5300_8',
 'CHEMBL3402741_400': 'CHEMBL3402741_400',
 'CHEMBL3402763_90': 'CHEMBL3402763_90',
 'CHEMBL3402764_90': 'CHEMBL3402764_90',
 'CHEMBL3402751_2100': 'CHEMBL3402751_2100_11',
 'CHEMBL3402756_2.7': 'CHEMBL3402756_2.7',
 'CHEMBL3402760_1': 'CHEMBL3402760_1'}
shp2_dict = {'SHP099-1/Example 7': 'SHP099-1',
 'Example 22': 'E22',
 'Example 29': 'E29',
 '11': '11',
 '4': '4',
 'Example 2': 'E2',
 'Example 14': 'E14',
 'Example 26': 'E26',
 'SHP836-2': 'SHP836-2',
 'Example 6': 'E6',
 'Example 1': 'E1',
 '3': '3',
 'Example 9': 'E9',
 'Example 8': 'E8',
 '7': '7',
 'Example 24': 'E24',
 'Example 28': 'E28',
 '10': '10',
 'Example 25': 'E25',
 'Example 27': 'E27',
 '6': '6',
 'Example 30': 'E30',
 'Example 5': 'E5',
 'Example 4': 'E4',
 'Example 23': 'E23',
 'Example 3': 'E3'}

# %%
def getSchindlerResults(target):
    file_name = f'{temp_directory}/{target}/results_edges_5ns.csv'
    if not os.path.exists(file_name):
        print(f'File {file_name} does not exist.')
        return None
    fepbenchmark5 = pd.read_csv(file_name)

    fepbenchmark5['ligandA'] = fepbenchmark5['Ligand1'].apply(lambda x: str(int(float(x))) if str(x).endswith('.0') else x)
    fepbenchmark5['ligandB'] = fepbenchmark5['Ligand2'].apply(lambda x: str(int(float(x))) if str(x).endswith('.0') else x)
    if target == 'cmet':
        for i, row in fepbenchmark5.iterrows():
            for lig in ['ligandA', 'ligandB']:
                if row[lig] in cmet_dict:
                    fepbenchmark5.loc[i, lig] = cmet_dict[row[lig]]    
    if target == "shp2":
        file_name = f'{temp_directory}/{target}/results_edges_20ns.csv'
        if not os.path.exists(file_name):
            print(f'File {file_name} does not exist.')
            return None
        fepbenchmark20= pd.read_csv(file_name)

        fepbenchmark20['ligandA'] = fepbenchmark20['Ligand1'].apply(lambda x: str(int(float(x))) if str(x).endswith('.0') else x)
        fepbenchmark20['ligandB'] = fepbenchmark20['Ligand2'].apply(lambda x: str(int(float(x))) if str(x).endswith('.0') else x)
        llist = []
        for i, row in fepbenchmark5.iterrows():
            for lig in ['ligandA', 'ligandB']:
                if row[lig] in shp2_dict:
                    fepbenchmark5.loc[i, lig] = shp2_dict[row[lig]]
            if pd.isna(row["FEP"]):
                nrow = fepbenchmark20.loc[i,:]
                assert row['Ligand1'] == nrow['Ligand1']
                assert row['Ligand2'] == nrow['Ligand2']
                fepbenchmark5.loc[i,"FEP"] = nrow["FEP"]
                fepbenchmark5.loc[i,"FEP Error"] = nrow["FEP Error"]
                llist.append(f'edge_{fepbenchmark5.loc[i,"ligandA"]}_{fepbenchmark5.loc[i,"ligandB"]}')
        print(f"{target} 20 ns runs",  llist)
    fepbenchmark5 = fepbenchmark5.loc[:, ['ligandA', 'ligandB', 'FEP', 'FEP Error']]
    fepbenchmark5 = fepbenchmark5.rename(columns={
                             'FEP': 'DDG',
                             'FEP Error': 'dDDG'})
    fepbenchmark5.index = [f'{target}_edge_{x["ligandA"]}_{x["ligandB"]}' for i, x in fepbenchmark5.iterrows()]
    fepbenchmark5['unit'] = 'kilocalories / mole'
    return fepbenchmark5
getSchindlerResults('hif2a').head()
# Out:
#                    ligandA ligandB   DDG  dDDG                 unit
# hif2a_edge_338_165     338     165 -0.44  0.25  kilocalories / mole
# hif2a_edge_338_215     338     215 -0.76  0.13  kilocalories / mole
# hif2a_edge_338_163     338     163 -1.02  0.10  kilocalories / mole
# hif2a_edge_43_235       43     235 -0.20  0.10  kilocalories / mole
# hif2a_edge_43_54        43      54  0.90  0.08  kilocalories / mole

# %%
author = 'schindler'
software = 'fep+'
forcefield = 'opls3e'

# %%
for target in targets.target_dict:
    df = getSchindlerResults(target)
    if df is None:
        continue
    os.makedirs(os.path.join(path, targets.get_target_dir(target), results_dir), exist_ok=True)
    with open(os.path.join(path, 
                           targets.get_target_dir(target), 
                           results_dir, 
                           f'{target}_{software}_{forcefield}_{author}.yaml'), 
              'w') as file:
        yaml.dump(df.T.to_dict(), file)
# Out:
# File /tmp/tmpaia1ucnz/jnk1/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/pde2/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/thrombin/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/p38/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/ptp1b/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/galectin/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/cdk2/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/mcl1/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/bace/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/bace_hunt/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/bace_p2/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/tyk2/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/ros1/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/pde10/results_edges_5ns.csv does not exist.
# shp2 20 ns runs ['edge_SHP099-1_E22', 'edge_SHP099-1_E2', 'edge_SHP099-1_E26', 'edge_E29_E9', 'edge_11_E25', 'edge_11_4', 'edge_E2_E1', 'edge_E26_SHP836-2', 'edge_E26_E6', 'edge_E6_E25', 'edge_E8_E30', 'edge_7_10', 'edge_E24_E30']

# %%
target='syk'
for target in targets.target_dict:
    author = "hahn"
    software = "experiment"
    file_name = os.path.join(path, targets.get_target_dir(target), results_dir, 
                                   f'{target}_{software}_{author}.yaml'
                       )
    if os.path.exists(file_name):
        with open(file_name, 'r') as file:
            data1 = yaml.safe_load(file)
    else:
        print(f"File {file_name} for target {target} not available")
        continue
        
    file_name = f'{temp_directory}/{target}/results_edges_5ns.csv'
    if not os.path.exists(file_name):
        print(f'File {file_name} does not exist.')
        continue
    fepbenchmark5 = pd.read_csv(file_name)
    fepbenchmark5['ligandA'] = fepbenchmark5['Ligand1'].apply(lambda x: str(int(float(x))) if str(x).endswith('.0') else x)
    fepbenchmark5['ligandB'] = fepbenchmark5['Ligand2'].apply(lambda x: str(int(float(x))) if str(x).endswith('.0') else x)
    if target == 'cmet':
        for i, row in fepbenchmark5.iterrows():
            for lig in ['ligandA', 'ligandB']:
                if row[lig] in cmet_dict:
                    fepbenchmark5.loc[i, lig] = cmet_dict[row[lig]]    
    if target == "shp2":
        file_name = f'{temp_directory}/{target}/results_edges_20ns.csv'
        if not os.path.exists(file_name):
            print(f'File {file_name} does not exist.')
            continue
        fepbenchmark20= pd.read_csv(file_name)

        fepbenchmark20['ligandA'] = fepbenchmark20['Ligand1'].apply(lambda x: str(int(float(x))) if str(x).endswith('.0') else x)
        fepbenchmark20['ligandB'] = fepbenchmark20['Ligand2'].apply(lambda x: str(int(float(x))) if str(x).endswith('.0') else x)
        llist = []
        for i, row in fepbenchmark5.iterrows():
            for lig in ['ligandA', 'ligandB']:
                if row[lig] in shp2_dict:
                    fepbenchmark5.loc[i, lig] = shp2_dict[row[lig]]
            if pd.isna(row["FEP"]):
                nrow = fepbenchmark20.loc[i,:]
                assert row['Ligand1'] == nrow['Ligand1']
                assert row['Ligand2'] == nrow['Ligand2']
                fepbenchmark5.loc[i,"FEP"] = nrow["FEP"]
                fepbenchmark5.loc[i,"FEP Error"] = nrow["FEP Error"]
                llist.append(f'edge_{fepbenchmark5.loc[i,"ligandA"]}_{fepbenchmark5.loc[i,"ligandB"]}')
        print(f"{target} 20 ns runs",  llist)
    fepbenchmark5 = fepbenchmark5.rename(columns={
                             'FEP': 'DDG',
                             'FEP Error': 'dDDG'})
    fepbenchmark5.index = [f'{target}_edge_{x["ligandA"]}_{x["ligandB"]}' for i, x in fepbenchmark5.iterrows()]
    fepbenchmark5['unit'] = 'kilocalories / mole'
    for e, edata in data1.items():
        v1 = unit_registry.Quantity(edata['DDG'], edata['unit'])
        v2 = unit_registry.Quantity(fepbenchmark5.loc[e, 'Exp.'], fepbenchmark5.loc[e, 'unit'])
        if not np.isclose(v1.to('kilocalories / mole').magnitude, 
                          v2.to('kilocalories / mole').magnitude, 
                              atol=.05,
                              equal_nan=False):
            print(target, e, v1.to('kilocalories / mole'), v2.to('kilocalories / mole'))
        #else:
        #    print(target, e)
    #print(data1, fepbenchmark5)
# Out:
# File /tmp/tmpaia1ucnz/jnk1/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/pde2/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/thrombin/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/p38/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/ptp1b/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/galectin/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/cdk2/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/mcl1/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/bace/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/bace_hunt/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/bace_p2/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/tyk2/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/ros1/results_edges_5ns.csv does not exist.
# File /tmp/tmpaia1ucnz/pde10/results_edges_5ns.csv does not exist.
# shp2 20 ns runs ['edge_SHP099-1_E22', 'edge_SHP099-1_E2', 'edge_SHP099-1_E26', 'edge_E29_E9', 'edge_11_E25', 'edge_11_4', 'edge_E2_E1', 'edge_E26_SHP836-2', 'edge_E26_E6', 'edge_E6_E25', 'edge_E8_E30', 'edge_7_10', 'edge_E24_E30']

# %% [markdown]
# # Create a simple, dump null model (all activities set to 0)

# %%
def getNullModell(target):
    edg = edges.EdgeSet(target)
    df = edg.get_dataframe(columns=[0,1])
    df = df.rename(columns={0: "ligandA", 1: "ligandB"})
    df.index = pd.Series([f'{target}_edge_' + str(lig1) + '_' + str(lig2) for lig1, lig2 in zip(df["ligandA"].values, df["ligandB"].values)])

    
    df['ligandA']= df['ligandA'].astype(str)
    df['ligandB']= df['ligandB'].astype(str)
    df['DDG'] = 0.0
    df['dDDG'] = 0.1
    df['unit'] = 'kilocalories / mole'
    return df
getNullModell('cmet').head()
# Out:
#                                                          ligandA  \
# cmet_edge_CHEMBL3402741_400_CHEMBL3402756_2.7  CHEMBL3402741_400
# cmet_edge_CHEMBL3402741_400_CHEMBL3402763_90   CHEMBL3402741_400
# cmet_edge_CHEMBL3402741_400_CHEMBL3402764_90   CHEMBL3402741_400
# cmet_edge_CHEMBL3402742_23_CHEMBL3402756_2.7    CHEMBL3402742_23
# cmet_edge_CHEMBL3402742_23_CHEMBL3402763_90     CHEMBL3402742_23
#
#                                                          ligandB  DDG  dDDG  \
# cmet_edge_CHEMBL3402741_400_CHEMBL3402756_2.7  CHEMBL3402756_2.7  0.0   0.1
# cmet_edge_CHEMBL3402741_400_CHEMBL3402763_90    CHEMBL3402763_90  0.0   0.1
# cmet_edge_CHEMBL3402741_400_CHEMBL3402764_90    CHEMBL3402764_90  0.0   0.1
# cmet_edge_CHEMBL3402742_23_CHEMBL3402756_2.7   CHEMBL3402756_2.7  0.0   0.1
# cmet_edge_CHEMBL3402742_23_CHEMBL3402763_90     CHEMBL3402763_90  0.0   0.1
#
#                                                               unit
# cmet_edge_CHEMBL3402741_400_CHEMBL3402756_2.7  kilocalories / mole
# cmet_edge_CHEMBL3402741_400_CHEMBL3402763_90   kilocalories / mole
# cmet_edge_CHEMBL3402741_400_CHEMBL3402764_90   kilocalories / mole
# cmet_edge_CHEMBL3402742_23_CHEMBL3402756_2.7   kilocalories / mole
# cmet_edge_CHEMBL3402742_23_CHEMBL3402763_90    kilocalories / mole

# %%
author = 'hahn'
software = 'null'
forcefield = 'null'

# %%
for target in targets.target_dict:
    df = getNullModell(target)
    if df is None:
        continue
    os.makedirs(os.path.join(path, targets.get_target_dir(target), results_dir), exist_ok=True)
    with open(os.path.join(path, targets.get_target_dir(target), results_dir, f'{target}_{software}_{forcefield}_{author}.yaml'), 'w') as file:
        yaml.dump(df.T.to_dict(), file)
